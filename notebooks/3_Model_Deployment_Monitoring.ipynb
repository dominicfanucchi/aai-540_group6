# %%
'''
This notebook is created to load, deploy, and monitor our Kmeans model. It utilizes CloudWatch alarms
and Sagemaker endpoints to accomplish these goals, as well as helper scripts as .py files. 
'''
# Out:
# '\nThis notebook is created to load, deploy, and monitor our Kmeans model. It utilizes CloudWatch alarms\nand Sagemaker endpoints to accomplish these goals, as well as helper scripts as .py files. \n'

# %%
# !pip install awswrangler
# Out:
# Requirement already satisfied: awswrangler in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.11.0)
# Requirement already satisfied: boto3<2.0.0,>=1.20.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (1.37.1)
# Requirement already satisfied: botocore<2.0.0,>=1.23.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (1.37.1)
# Requirement already satisfied: numpy<3.0,>=1.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (1.26.4)
# Requirement already satisfied: packaging<25.0,>=21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (21.3)
# Requirement already satisfied: pandas<3.0.0,>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (1.5.3)
# Requirement already satisfied: pyarrow<19.0.0,>=8.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (18.1.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from awswrangler) (4.12.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.20.32->awswrangler) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.20.32->awswrangler) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<2.0.0,>=1.23.32->awswrangler) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<2.0.0,>=1.23.32->awswrangler) (2.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging<25.0,>=21.1->awswrangler) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.23.32->awswrangler) (1.17.0)

# %%
# Need to shuffle helper script around due to peculiar issues
# !mv code/inference.py inference.py

# %%
import os
import boto3
import shutil
import numpy as np
import pandas as pd
import time
import io
import sagemaker
import awswrangler as wr
from datetime import datetime
from sagemaker.model import Model
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer, JSONSerializer
from sagemaker.deserializers import JSONDeserializer
from inference import model_fn, input_fn, predict_fn, output_fn
from sagemaker.model_monitor import ModelQualityMonitor, CronExpressionGenerator, EndpointInput, DataCaptureConfig

# CloudWatch client (for alarms)
cw_client = boto3.client("cloudwatch", region_name="us-east-1")

bucket_name = "arxiv-project-bucket"
role = "arn:aws:iam::221082214706:role/MYLabRole"
region = "us-east-1"

sess = sagemaker.Session(boto_session=boto3.Session(region_name=region))
print("Using bucket:", bucket_name)

# S3 path for the trained model from model training notebook
model_s3_path = f"s3://{bucket_name}/models/model.tar.gz"
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [03/04/25 01:05:45] INFO     Found credentials from IAM Role:                                   ]8;id=572878;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=434516;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# [03/04/25 01:05:48] INFO     Found credentials from IAM Role:                                   ]8;id=493106;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=668500;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
#                     INFO     Found credentials from IAM Role:                                   ]8;id=188045;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=222890;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# Using bucket: arxiv-project-bucket

# %%
# Need a suitable scikit-learn container image for inference
sklearn_image_uri = sagemaker.image_uris.retrieve(
    framework="sklearn",
    region=region,
    version="1.2-1", # Source of many errors, set version to same as in training
    py_version="py3"
)
print("Scikit-Learn container image:", sklearn_image_uri)
# Out:
#                     INFO     Defaulting to only supported image scope: cpu.                       ]8;id=71331;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=453313;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py#534\534]8;;\
# Scikit-Learn container image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3

# %%
'''
NOTE: 
In model deployment below, when definining model, I set directory to code folder within my local AWS notebook. 
I specialized the directory to include inference.py because calling the local directory where all files are hosted, 
and where inference.py was previously hosted, caused Sagemaekr to package all of those causing permission and size issues, 
crashing our endpoint deployment.
'''
# Out:
# '\nNOTE: \nIn model deployment below, when definining model, I set directory to code folder within my local AWS notebook. \nI specialized the directory to include inference.py because calling the local directory where all files are hosted, \nand where inference.py was previously hosted, caused Sagemaekr to package all of those causing permission and size issues, \ncrashing our endpoint deployment.\n'

# %%
target_dir = "code"
# Move inference.py into the code folder
shutil.move("inference.py", os.path.join(target_dir, "inference.py"))
print("Moved inference.py to the 'code' directory.")
# Out:
# Moved inference.py to the 'code' directory.

# %%
# SageMaker Model using the SKLearn container and our inference script
model = sagemaker.Model(
    model_data=model_s3_path,
    image_uri=sklearn_image_uri,
    role=role,
    entry_point="inference.py",
    source_dir="code",
    sagemaker_session=sess
)

data_capture_config = DataCaptureConfig(
    enable_capture=True,
    sampling_percentage=100,
    destination_s3_uri=f"s3://{bucket_name}/data-capture"
)

# Deploy the model as an endpoint and return a predictor object
endpoint_name = "arxiv-clustering-endpoint" + datetime.utcnow().strftime("%Y%m%d%H%M%S")

predictor = model.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.xlarge",
    endpoint_name=endpoint_name,
    data_capture_config=data_capture_config
)

print("Endpoint deployed:", endpoint_name)
# Out:
# [03/04/25 01:05:49] INFO     Repacking model artifact (s3://arxiv-project-bucket/models/model.tar.gz), ]8;id=417605;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model.py\model.py]8;;\:]8;id=355292;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model.py#819\819]8;;\
#                              script artifact (code), and dependencies ([]) into single tar.gz file
#                              located at
#                              s3://sagemaker-us-east-1-221082214706/sagemaker-scikit-learn-2025-03-04-0
#                              1-05-48-955/model.tar.gz. This may take some time depending on model
#                              size...
# [03/04/25 01:05:52] INFO     Creating model with name:                                              ]8;id=233570;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=232313;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#4094\4094]8;;\
#                              sagemaker-scikit-learn-2025-03-04-01-05-52-886
# [03/04/25 01:05:53] INFO     Creating endpoint-config with name                                     ]8;id=153037;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=100537;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#5889\5889]8;;\
#                              arxiv-clustering-endpoint20250304010548
#                     INFO     Creating endpoint with name arxiv-clustering-endpoint20250304010548    ]8;id=307819;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=391867;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#4711\4711]8;;\
# ------!Endpoint deployed: arxiv-clustering-endpoint20250304010548

# %%
predictor = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sess,
    serializer=JSONSerializer(), 
    deserializer=JSONDeserializer()
)

# %%
status = sess.describe_endpoint(endpoint_name)["EndpointStatus"]
while status != "InService":
    print("Endpoint status:", status)
    time.sleep(10)
    status = sess.describe_endpoint(endpoint_name)["EndpointStatus"]
print("Endpoint is in service!")
# Out:
# Endpoint is in service!

# %%
print("Predictor:", predictor)
# Out:
# Predictor: Predictor: {'endpoint_name': 'arxiv-clustering-endpoint20250304010548', 'sagemaker_session': <sagemaker.session.Session object at 0x7f978267ee00>, 'serializer': <sagemaker.base_serializers.JSONSerializer object at 0x7f97806a5750>, 'deserializer': <sagemaker.base_deserializers.JSONDeserializer object at 0x7f9780b94550>}

# %%
# Create a CloudWatch Logs client
logs_client = boto3.client("logs", region_name=region)

# Define the log group name based on your endpoint name
log_group = f"/aws/sagemaker/Endpoints/{endpoint_name}"

# Describe log streams in the log group
response = logs_client.describe_log_streams(logGroupName=log_group)
log_streams = response.get("logStreams", [])

if log_streams:
    log_stream_name = log_streams[0]["logStreamName"]
    events_response = logs_client.get_log_events(
        logGroupName=log_group, 
        logStreamName=log_stream_name
    )
    for event in events_response.get("events", []):
        print(event["message"])
else:
    print("No log streams found in log group:", log_group)
# Out:
# 2025-03-04 01:08:31,834 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2025-03-04 01:08:31,836 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2025-03-04 01:08:31,836 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# 2025-03-04 01:08:31,840 INFO - sagemaker-containers - Module inference does not provide a setup.py.
# Generating setup.py
# 2025-03-04 01:08:31,840 INFO - sagemaker-containers - Generating setup.cfg
# 2025-03-04 01:08:31,840 INFO - sagemaker-containers - Generating MANIFEST.in
# 2025-03-04 01:08:31,840 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python3 -m pip install .
# Processing /opt/ml/code
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: inference
#   Building wheel for inference (setup.py): started
#   Building wheel for inference (setup.py): finished with status 'done'
#   Created wheel for inference: filename=inference-1.0.0-py2.py3-none-any.whl size=6788 sha256=66dc45952b7217641fd084d39c9d8327c1f9857a6e0a8ae8e9c2f94ce6cbf6a7
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-siolqm5k/wheels/40/03/3a/5f39818cea87b3c154b54d046a775b3da4b8ed9b642b8d50e6
# Successfully built inference
# Installing collected packages: inference
# Successfully installed inference-1.0.0
# [2025-03-04 01:08:33 +0000] [24] [INFO] Starting gunicorn 20.0.4
# [2025-03-04 01:08:33 +0000] [24] [INFO] Listening at: unix:/tmp/gunicorn.sock (24)
# [2025-03-04 01:08:33 +0000] [24] [INFO] Using worker: gevent
# [2025-03-04 01:08:33 +0000] [25] [INFO] Booting worker with pid: 25
# [2025-03-04 01:08:33 +0000] [26] [INFO] Booting worker with pid: 26
# [2025-03-04 01:08:33 +0000] [27] [INFO] Booting worker with pid: 27
# [2025-03-04 01:08:33 +0000] [28] [INFO] Booting worker with pid: 28
# 2025-03-04 01:08:34,798 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2025-03-04 01:08:34,999 INFO - inference - Loading model from /opt/ml/model/kmeans_arxiv_model.joblib
# /miniconda3/lib/python3.9/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator KMeans from version 1.2.0 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2025-03-04 01:08:35,356 INFO - inference - Model loaded successfully.
# 169.254.178.2 - - [04/Mar/2025:01:08:35 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 2025-03-04 01:08:39,779 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2025-03-04 01:08:39,980 INFO - inference - Loading model from /opt/ml/model/kmeans_arxiv_model.joblib
# /miniconda3/lib/python3.9/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator KMeans from version 1.2.0 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2025-03-04 01:08:40,334 INFO - inference - Model loaded successfully.
# 169.254.178.2 - - [04/Mar/2025:01:08:40 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 2025-03-04 01:08:44,779 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2025-03-04 01:08:44,987 INFO - inference - Loading model from /opt/ml/model/kmeans_arxiv_model.joblib
# /miniconda3/lib/python3.9/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator KMeans from version 1.2.0 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2025-03-04 01:08:45,344 INFO - inference - Model loaded successfully.
# 169.254.178.2 - - [04/Mar/2025:01:08:45 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 2025-03-04 01:08:49,779 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2025-03-04 01:08:49,982 INFO - inference - Loading model from /opt/ml/model/kmeans_arxiv_model.joblib
# /miniconda3/lib/python3.9/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator KMeans from version 1.2.0 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 2025-03-04 01:08:50,330 INFO - inference - Model loaded successfully.
# 169.254.178.2 - - [04/Mar/2025:01:08:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 169.254.178.2 - - [04/Mar/2025:01:08:54 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 169.254.178.2 - - [04/Mar/2025:01:08:59 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 169.254.178.2 - - [04/Mar/2025:01:09:04 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 169.254.178.2 - - [04/Mar/2025:01:09:09 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"
# 169.254.178.2 - - [04/Mar/2025:01:09:14 +0000] "GET /ping HTTP/1.1" 200 0 "-" "AHC/2.0"

# %%
desc = sess.sagemaker_client.describe_endpoint(EndpointName=endpoint_name)
print("Endpoint description:", desc)
# Out:
# Endpoint description: {'EndpointName': 'arxiv-clustering-endpoint20250304010548', 'EndpointArn': 'arn:aws:sagemaker:us-east-1:221082214706:endpoint/arxiv-clustering-endpoint20250304010548', 'EndpointConfigName': 'arxiv-clustering-endpoint20250304010548', 'ProductionVariants': [{'VariantName': 'AllTraffic', 'DeployedImages': [{'SpecifiedImage': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3', 'ResolvedImage': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn@sha256:9ff74d76191b625518d00824d43608641042302d446dbb72b01417be51ec4854', 'ResolutionTime': datetime.datetime(2025, 3, 4, 1, 5, 55, 123000, tzinfo=tzlocal())}], 'CurrentWeight': 1.0, 'DesiredWeight': 1.0, 'CurrentInstanceCount': 1, 'DesiredInstanceCount': 1}], 'DataCaptureConfig': {'EnableCapture': True, 'CaptureStatus': 'Started', 'CurrentSamplingPercentage': 100, 'DestinationS3Uri': 's3://arxiv-project-bucket/data-capture'}, 'EndpointStatus': 'InService', 'CreationTime': datetime.datetime(2025, 3, 4, 1, 5, 54, 167000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2025, 3, 4, 1, 9, 5, 764000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '215bf582-b320-4b4d-8cdb-cae3b3009614', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '215bf582-b320-4b4d-8cdb-cae3b3009614', 'content-type': 'application/x-amz-json-1.1', 'content-length': '941', 'date': 'Tue, 04 Mar 2025 01:09:25 GMT'}, 'RetryAttempts': 0}}

# %%
# We should test the (hopefully) deployed endpoint with a test input
# Create a sample input with 50 dimensional output
# Has to match the n_dim value in our first notebook in SVD
sample_input = np.random.rand(1, 50).tolist()
print("Sending sample input:", sample_input)

# Call the endpoint and predictor should invoke your inference.py code
response = predictor.predict(sample_input)
print("Endpoint response:", response)
# Out:
# Sending sample input: [[0.4390833519394989, 0.6401406333983879, 0.7566341858810585, 0.9720417493628968, 0.5508708528426888, 0.206584335696397, 0.28500506530350733, 0.34108946407854945, 0.17839809359803105, 0.3652364271944426, 0.7174211538274556, 0.9292912230707593, 0.7611759942129664, 0.5822065915242812, 0.023003686486261388, 0.5834347725824839, 0.7220893508009194, 0.9491631862843318, 0.9057384311553117, 0.19428960652030536, 0.10622479636593729, 0.41323025621421017, 0.5685681495961176, 0.8817279084737528, 0.35382308701497667, 0.8449841588969577, 0.8204304623841299, 0.8548246482438826, 0.07444425272495236, 0.30544665928005954, 0.21625248481673676, 0.8420845783481145, 0.9798392133992908, 0.33147000453747677, 0.6956830083464318, 0.2787275444765902, 0.2405942079688408, 0.33782404699678137, 0.6677406036320244, 0.2214544834602633, 0.9101609665680681, 0.46436093772342235, 0.11221768626027973, 0.7592675717438081, 0.45227872018909543, 0.9142770224924576, 0.7266199955867158, 0.9394816450437943, 0.10919589786411421, 0.16153379785182587]]
# Endpoint response: {'prediction': [2]}

# %%
# From here we will use the test results to generate an idea of our model and a baseline for our results

# %%
# With Model Deployed, going to generate baseline predictions from test data and push it to S3
test_data_prefix = f"s3://{bucket_name}/processed_csv/test/"

# List all test files in our prefix
test_files = wr.s3.list_objects(path=test_data_prefix)
print("Test files:", test_files)

# Concatenate all test CSV files into a single DataFrame
df_test = pd.concat([wr.s3.read_csv(file) for file in test_files], ignore_index=True)
print("Combined test data shape:", df_test.shape)
# Out:
# Test files: ['s3://arxiv-project-bucket/processed_csv/test/arxiv_test_2022.csv', 's3://arxiv-project-bucket/processed_csv/test/arxiv_test_2023.csv']
# Combined test data shape: (414530, 59)

# %%
# Need to sample because kernel dies, overloads, and crashes AWS account
df_test_sampled = df_test.sample(n=20000, random_state=39)
print("Sampled test data shape:", df_test_sampled.shape)
# Out:
# Sampled test data shape: (20000, 59)

# %%
# Extract numeric features for clustering.
# We assume that your preprocessing created SVD features with names like "svd_0", "svd_1", ..., "svd_49".
svd_cols = [col for col in df_test.columns if col.startswith("svd_")]
if not svd_cols:
    raise ValueError("No SVD columns found in test data.")
X_test = df_test_sampled[svd_cols].values
print("Test feature matrix shape:", X_test.shape)
# Out:
# Test feature matrix shape: (20000, 50)

# %%
# Set batch size to 1 to avoid overloading and crashing the kernel with 500 error

# %%
# Generate predictions on the test data using the deployed endpoint.
# Need to batch in or we will get a 500 error return for overloading server

def batch_predict(predictor, X, batch_size=1):
    all_predictions = []
    n = len(X)
    for i in range(0, n, batch_size):
        batch = X[i:i+batch_size]
        # If the batch is empty, break out of the loop
        if batch.size == 0:
            break
        preds = predictor.predict(batch.tolist())
        # If preds is None or not an array, skip this batch
        if preds is None:
            print(f"Batch {i//batch_size + 1} returned None, skipping.")
            continue
        preds_arr = np.atleast_1d(preds)
        # If the predictions array is empty, skip
        if preds_arr.size == 0:
            print(f"Batch {i//batch_size + 1} returned an empty prediction, skipping.")
            continue
        all_predictions.append(preds_arr)
        print(f"Processed batch {i//batch_size + 1} / {int(np.ceil(n / batch_size))}")
    if len(all_predictions) == 0:
        return np.array([])
    return np.concatenate(all_predictions)

# X_test is our test feature matrix, so input here
predictions = batch_predict(predictor, X_test, batch_size=1)
baseline_df = pd.DataFrame({"prediction": predictions.flatten()})

# Create a baseline DataFrame from the predictions.
baseline_df = pd.DataFrame({"prediction": predictions.flatten()})
# (If you have ground truth values available, you could include them as well.)
# Out:
# Processed batch 1 / 20000
# Processed batch 2 / 20000
# Processed batch 3 / 20000
# Processed batch 4 / 20000
# Processed batch 5 / 20000
# Processed batch 6 / 20000
# Processed batch 7 / 20000
# Processed batch 8 / 20000
# Processed batch 9 / 20000
# Processed batch 10 / 20000
# Processed batch 11 / 20000
# Processed batch 12 / 20000
# Processed batch 13 / 20000
# Processed batch 14 / 20000
# Processed batch 15 / 20000
# Processed batch 16 / 20000
# Processed batch 17 / 20000
# Processed batch 18 / 20000
# Processed batch 19 / 20000
# Processed batch 20 / 20000
# Processed batch 21 / 20000
# Processed batch 22 / 20000
# Processed batch 23 / 20000
# Processed batch 24 / 20000
# Processed batch 25 / 20000
# Processed batch 26 / 20000
# Processed batch 27 / 20000
# Processed batch 28 / 20000
# Processed batch 29 / 20000
# Processed batch 30 / 20000
# Processed batch 31 / 20000
# Processed batch 32 / 20000
# Processed batch 33 / 20000
# Processed batch 34 / 20000
# Processed batch 35 / 20000
# Processed batch 36 / 20000
# Processed batch 37 / 20000
# Processed batch 38 / 20000
# Processed batch 39 / 20000
# Processed batch 40 / 20000
# Processed batch 41 / 20000
# Processed batch 42 / 20000
# Processed batch 43 / 20000
# Processed batch 44 / 20000
# Processed batch 45 / 20000
# Processed batch 46 / 20000
# Processed batch 47 / 20000
# Processed batch 48 / 20000
# Processed batch 49 / 20000
# Processed batch 50 / 20000
# Processed batch 51 / 20000
# Processed batch 52 / 20000
# Processed batch 53 / 20000
# Processed batch 54 / 20000
# Processed batch 55 / 20000
# Processed batch 56 / 20000
# Processed batch 57 / 20000
# Processed batch 58 / 20000
# Processed batch 59 / 20000
# Processed batch 60 / 20000
# Processed batch 61 / 20000
# Processed batch 62 / 20000
# Processed batch 63 / 20000
# Processed batch 64 / 20000
# Processed batch 65 / 20000
# Processed batch 66 / 20000
# Processed batch 67 / 20000
# Processed batch 68 / 20000
# Processed batch 69 / 20000
# Processed batch 70 / 20000
# Processed batch 71 / 20000
# Processed batch 72 / 20000
# Processed batch 73 / 20000
# Processed batch 74 / 20000
# Processed batch 75 / 20000
# Processed batch 76 / 20000
# Processed batch 77 / 20000
# Processed batch 78 / 20000
# Processed batch 79 / 20000
# Processed batch 80 / 20000
# Processed batch 81 / 20000
# Processed batch 82 / 20000
# Processed batch 83 / 20000
# Processed batch 84 / 20000
# Processed batch 85 / 20000
# Processed batch 86 / 20000
# Processed batch 87 / 20000
# Processed batch 88 / 20000
# Processed batch 89 / 20000
# Processed batch 90 / 20000
# Processed batch 91 / 20000
# Processed batch 92 / 20000
# Processed batch 93 / 20000
# Processed batch 94 / 20000
# Processed batch 95 / 20000
# Processed batch 96 / 20000
# Processed batch 97 / 20000
# Processed batch 98 / 20000
# Processed batch 99 / 20000
# Processed batch 100 / 20000
# Processed batch 101 / 20000
# Processed batch 102 / 20000
# Processed batch 103 / 20000
# Processed batch 104 / 20000
# Processed batch 105 / 20000
# Processed batch 106 / 20000
# Processed batch 107 / 20000
# Processed batch 108 / 20000
# Processed batch 109 / 20000
# Processed batch 110 / 20000
# Processed batch 111 / 20000
# Processed batch 112 / 20000
# Processed batch 113 / 20000
# Processed batch 114 / 20000
# Processed batch 115 / 20000
# Processed batch 116 / 20000
# Processed batch 117 / 20000
# Processed batch 118 / 20000
# Processed batch 119 / 20000
# Processed batch 120 / 20000
# Processed batch 121 / 20000
# Processed batch 122 / 20000
# Processed batch 123 / 20000
# Processed batch 124 / 20000
# Processed batch 125 / 20000
# Processed batch 126 / 20000
# Processed batch 127 / 20000
# Processed batch 128 / 20000
# Processed batch 129 / 20000
# Processed batch 130 / 20000
# Processed batch 131 / 20000
# Processed batch 132 / 20000
# Processed batch 133 / 20000
# Processed batch 134 / 20000
# Processed batch 135 / 20000
# Processed batch 136 / 20000
# Processed batch 137 / 20000
# Processed batch 138 / 20000
# Processed batch 139 / 20000
# Processed batch 140 / 20000
# Processed batch 141 / 20000
# Processed batch 142 / 20000
# Processed batch 143 / 20000
# Processed batch 144 / 20000
# Processed batch 145 / 20000
# Processed batch 146 / 20000
# Processed batch 147 / 20000
# Processed batch 148 / 20000
# Processed batch 149 / 20000
# Processed batch 150 / 20000
# Processed batch 151 / 20000
# Processed batch 152 / 20000
# Processed batch 153 / 20000
# Processed batch 154 / 20000
# Processed batch 155 / 20000
# Processed batch 156 / 20000
# Processed batch 157 / 20000
# Processed batch 158 / 20000
# Processed batch 159 / 20000
# Processed batch 160 / 20000
# Processed batch 161 / 20000
# Processed batch 162 / 20000
# Processed batch 163 / 20000
# Processed batch 164 / 20000
# Processed batch 165 / 20000
# Processed batch 166 / 20000
# Processed batch 167 / 20000
# Processed batch 168 / 20000
# Processed batch 169 / 20000
# Processed batch 170 / 20000
# Processed batch 171 / 20000
# Processed batch 172 / 20000
# Processed batch 173 / 20000
# Processed batch 174 / 20000
# Processed batch 175 / 20000
# Processed batch 176 / 20000
# Processed batch 177 / 20000
# Processed batch 178 / 20000
# Processed batch 179 / 20000
# Processed batch 180 / 20000
# Processed batch 181 / 20000
# Processed batch 182 / 20000
# Processed batch 183 / 20000
# Processed batch 184 / 20000
# Processed batch 185 / 20000
# Processed batch 186 / 20000
# Processed batch 187 / 20000
# Processed batch 188 / 20000
# Processed batch 189 / 20000
# Processed batch 190 / 20000
# Processed batch 191 / 20000
# Processed batch 192 / 20000
# Processed batch 193 / 20000
# Processed batch 194 / 20000
# Processed batch 195 / 20000
# Processed batch 196 / 20000
# Processed batch 197 / 20000
# Processed batch 198 / 20000
# Processed batch 199 / 20000
# Processed batch 200 / 20000
# Processed batch 201 / 20000
# Processed batch 202 / 20000
# Processed batch 203 / 20000
# Processed batch 204 / 20000
# Processed batch 205 / 20000
# Processed batch 206 / 20000
# Processed batch 207 / 20000
# Processed batch 208 / 20000
# Processed batch 209 / 20000
# Processed batch 210 / 20000
# Processed batch 211 / 20000
# Processed batch 212 / 20000
# Processed batch 213 / 20000
# Processed batch 214 / 20000
# Processed batch 215 / 20000
# Processed batch 216 / 20000
# Processed batch 217 / 20000
# Processed batch 218 / 20000
# Processed batch 219 / 20000
# Processed batch 220 / 20000
# Processed batch 221 / 20000
# Processed batch 222 / 20000
# Processed batch 223 / 20000
# Processed batch 224 / 20000
# Processed batch 225 / 20000
# Processed batch 226 / 20000
# Processed batch 227 / 20000
# Processed batch 228 / 20000
# Processed batch 229 / 20000
# Processed batch 230 / 20000
# Processed batch 231 / 20000
# Processed batch 232 / 20000
# Processed batch 233 / 20000
# Processed batch 234 / 20000
# Processed batch 235 / 20000
# Processed batch 236 / 20000
# Processed batch 237 / 20000
# Processed batch 238 / 20000
# Processed batch 239 / 20000
# Processed batch 240 / 20000
# Processed batch 241 / 20000
# Processed batch 242 / 20000
# Processed batch 243 / 20000
# Processed batch 244 / 20000
# Processed batch 245 / 20000
# Processed batch 246 / 20000
# Processed batch 247 / 20000
# Processed batch 248 / 20000
# Processed batch 249 / 20000
# Processed batch 250 / 20000
# Processed batch 251 / 20000
# Processed batch 252 / 20000
# Processed batch 253 / 20000
# Processed batch 254 / 20000
# Processed batch 255 / 20000
# Processed batch 256 / 20000
# Processed batch 257 / 20000
# Processed batch 258 / 20000
# Processed batch 259 / 20000
# Processed batch 260 / 20000
# Processed batch 261 / 20000
# Processed batch 262 / 20000
# Processed batch 263 / 20000
# Processed batch 264 / 20000
# Processed batch 265 / 20000
# Processed batch 266 / 20000
# Processed batch 267 / 20000
# Processed batch 268 / 20000
# Processed batch 269 / 20000
# Processed batch 270 / 20000
# Processed batch 271 / 20000
# Processed batch 272 / 20000
# Processed batch 273 / 20000
# Processed batch 274 / 20000
# Processed batch 275 / 20000
# Processed batch 276 / 20000
# Processed batch 277 / 20000
# Processed batch 278 / 20000
# Processed batch 279 / 20000
# Processed batch 280 / 20000
# Processed batch 281 / 20000
# Processed batch 282 / 20000
# Processed batch 283 / 20000
# Processed batch 284 / 20000
# Processed batch 285 / 20000
# Processed batch 286 / 20000
# Processed batch 287 / 20000
# Processed batch 288 / 20000
# Processed batch 289 / 20000
# Processed batch 290 / 20000
# Processed batch 291 / 20000
# Processed batch 292 / 20000
# Processed batch 293 / 20000
# Processed batch 294 / 20000
# Processed batch 295 / 20000
# Processed batch 296 / 20000
# Processed batch 297 / 20000
# Processed batch 298 / 20000
# Processed batch 299 / 20000
# Processed batch 300 / 20000
# Processed batch 301 / 20000
# Processed batch 302 / 20000
# Processed batch 303 / 20000
# Processed batch 304 / 20000
# Processed batch 305 / 20000
# Processed batch 306 / 20000
# Processed batch 307 / 20000
# Processed batch 308 / 20000
# Processed batch 309 / 20000
# Processed batch 310 / 20000
# Processed batch 311 / 20000
# Processed batch 312 / 20000
# Processed batch 313 / 20000
# Processed batch 314 / 20000
# Processed batch 315 / 20000
# Processed batch 316 / 20000
# Processed batch 317 / 20000
# Processed batch 318 / 20000
# Processed batch 319 / 20000
# Processed batch 320 / 20000
# Processed batch 321 / 20000
# Processed batch 322 / 20000
# Processed batch 323 / 20000
# Processed batch 324 / 20000
# Processed batch 325 / 20000
# Processed batch 326 / 20000
# Processed batch 327 / 20000
# Processed batch 328 / 20000
# Processed batch 329 / 20000
# Processed batch 330 / 20000
# Processed batch 331 / 20000
# Processed batch 332 / 20000
# Processed batch 333 / 20000
# Processed batch 334 / 20000
# Processed batch 335 / 20000
# Processed batch 336 / 20000
# Processed batch 337 / 20000
# Processed batch 338 / 20000
# Processed batch 339 / 20000
# Processed batch 340 / 20000
# Processed batch 341 / 20000
# Processed batch 342 / 20000
# Processed batch 343 / 20000
# Processed batch 344 / 20000
# Processed batch 345 / 20000
# Processed batch 346 / 20000
# Processed batch 347 / 20000
# Processed batch 348 / 20000
# Processed batch 349 / 20000
# Processed batch 350 / 20000
# Processed batch 351 / 20000
# Processed batch 352 / 20000
# Processed batch 353 / 20000
# Processed batch 354 / 20000
# Processed batch 355 / 20000
# Processed batch 356 / 20000
# Processed batch 357 / 20000
# Processed batch 358 / 20000
# Processed batch 359 / 20000
# Processed batch 360 / 20000
# Processed batch 361 / 20000
# Processed batch 362 / 20000
# Processed batch 363 / 20000
# Processed batch 364 / 20000
# Processed batch 365 / 20000
# Processed batch 366 / 20000
# Processed batch 367 / 20000
# Processed batch 368 / 20000
# Processed batch 369 / 20000
# Processed batch 370 / 20000
# Processed batch 371 / 20000
# Processed batch 372 / 20000
# Processed batch 373 / 20000
# Processed batch 374 / 20000
# Processed batch 375 / 20000
# Processed batch 376 / 20000
# Processed batch 377 / 20000
# Processed batch 378 / 20000
# Processed batch 379 / 20000
# Processed batch 380 / 20000
# Processed batch 381 / 20000
# Processed batch 382 / 20000
# Processed batch 383 / 20000
# Processed batch 384 / 20000
# Processed batch 385 / 20000
# Processed batch 386 / 20000
# Processed batch 387 / 20000
# Processed batch 388 / 20000
# Processed batch 389 / 20000
# Processed batch 390 / 20000
# Processed batch 391 / 20000
# Processed batch 392 / 20000
# Processed batch 393 / 20000
# Processed batch 394 / 20000
# Processed batch 395 / 20000
# Processed batch 396 / 20000
# Processed batch 397 / 20000
# Processed batch 398 / 20000
# Processed batch 399 / 20000
# Processed batch 400 / 20000
# Processed batch 401 / 20000
# Processed batch 402 / 20000
# Processed batch 403 / 20000
# Processed batch 404 / 20000
# Processed batch 405 / 20000
# Processed batch 406 / 20000
# Processed batch 407 / 20000
# Processed batch 408 / 20000
# Processed batch 409 / 20000
# Processed batch 410 / 20000
# Processed batch 411 / 20000
# Processed batch 412 / 20000
# Processed batch 413 / 20000
# Processed batch 414 / 20000
# Processed batch 415 / 20000
# Processed batch 416 / 20000
# Processed batch 417 / 20000
# Processed batch 418 / 20000
# Processed batch 419 / 20000
# Processed batch 420 / 20000
# Processed batch 421 / 20000
# Processed batch 422 / 20000
# Processed batch 423 / 20000
# Processed batch 424 / 20000
# Processed batch 425 / 20000
# Processed batch 426 / 20000
# Processed batch 427 / 20000
# Processed batch 428 / 20000
# Processed batch 429 / 20000
# Processed batch 430 / 20000
# Processed batch 431 / 20000
# Processed batch 432 / 20000
# Processed batch 433 / 20000
# Processed batch 434 / 20000
# Processed batch 435 / 20000
# Processed batch 436 / 20000
# Processed batch 437 / 20000
# Processed batch 438 / 20000
# Processed batch 439 / 20000
# Processed batch 440 / 20000
# Processed batch 441 / 20000
# Processed batch 442 / 20000
# Processed batch 443 / 20000
# Processed batch 444 / 20000
# Processed batch 445 / 20000
# Processed batch 446 / 20000
# Processed batch 447 / 20000
# Processed batch 448 / 20000
# Processed batch 449 / 20000
# Processed batch 450 / 20000
# Processed batch 451 / 20000
# Processed batch 452 / 20000
# Processed batch 453 / 20000
# Processed batch 454 / 20000
# Processed batch 455 / 20000
# Processed batch 456 / 20000
# Processed batch 457 / 20000
# Processed batch 458 / 20000
# Processed batch 459 / 20000
# Processed batch 460 / 20000
# Processed batch 461 / 20000
# Processed batch 462 / 20000
# Processed batch 463 / 20000
# Processed batch 464 / 20000
# Processed batch 465 / 20000
# Processed batch 466 / 20000
# Processed batch 467 / 20000
# Processed batch 468 / 20000
# Processed batch 469 / 20000
# Processed batch 470 / 20000
# Processed batch 471 / 20000
# Processed batch 472 / 20000
# Processed batch 473 / 20000
# Processed batch 474 / 20000
# Processed batch 475 / 20000
# Processed batch 476 / 20000
# Processed batch 477 / 20000
# Processed batch 478 / 20000
# Processed batch 479 / 20000
# Processed batch 480 / 20000
# Processed batch 481 / 20000
# Processed batch 482 / 20000
# Processed batch 483 / 20000
# Processed batch 484 / 20000
# Processed batch 485 / 20000
# Processed batch 486 / 20000
# Processed batch 487 / 20000
# Processed batch 488 / 20000
# Processed batch 489 / 20000
# Processed batch 490 / 20000
# Processed batch 491 / 20000
# Processed batch 492 / 20000
# Processed batch 493 / 20000
# Processed batch 494 / 20000
# Processed batch 495 / 20000
# Processed batch 496 / 20000
# Processed batch 497 / 20000
# Processed batch 498 / 20000
# Processed batch 499 / 20000
# Processed batch 500 / 20000
# Processed batch 501 / 20000
# Processed batch 502 / 20000
# Processed batch 503 / 20000
# Processed batch 504 / 20000
# Processed batch 505 / 20000
# Processed batch 506 / 20000
# Processed batch 507 / 20000
# Processed batch 508 / 20000
# Processed batch 509 / 20000
# Processed batch 510 / 20000
# Processed batch 511 / 20000
# Processed batch 512 / 20000
# Processed batch 513 / 20000
# Processed batch 514 / 20000
# Processed batch 515 / 20000
# Processed batch 516 / 20000
# Processed batch 517 / 20000
# Processed batch 518 / 20000
# Processed batch 519 / 20000
# Processed batch 520 / 20000
# Processed batch 521 / 20000
# Processed batch 522 / 20000
# Processed batch 523 / 20000
# Processed batch 524 / 20000
# Processed batch 525 / 20000
# Processed batch 526 / 20000
# Processed batch 527 / 20000
# Processed batch 528 / 20000
# Processed batch 529 / 20000
# Processed batch 530 / 20000
# Processed batch 531 / 20000
# Processed batch 532 / 20000
# Processed batch 533 / 20000
# Processed batch 534 / 20000
# Processed batch 535 / 20000
# Processed batch 536 / 20000
# Processed batch 537 / 20000
# Processed batch 538 / 20000
# Processed batch 539 / 20000
# Processed batch 540 / 20000
# Processed batch 541 / 20000
# Processed batch 542 / 20000
# Processed batch 543 / 20000
# Processed batch 544 / 20000
# Processed batch 545 / 20000
# Processed batch 546 / 20000
# Processed batch 547 / 20000
# Processed batch 548 / 20000
# Processed batch 549 / 20000
# Processed batch 550 / 20000
# Processed batch 551 / 20000
# Processed batch 552 / 20000
# Processed batch 553 / 20000
# Processed batch 554 / 20000
# Processed batch 555 / 20000
# Processed batch 556 / 20000
# Processed batch 557 / 20000
# Processed batch 558 / 20000
# Processed batch 559 / 20000
# Processed batch 560 / 20000
# Processed batch 561 / 20000
# Processed batch 562 / 20000
# Processed batch 563 / 20000
# Processed batch 564 / 20000
# Processed batch 565 / 20000
# Processed batch 566 / 20000
# Processed batch 567 / 20000
# Processed batch 568 / 20000
# Processed batch 569 / 20000
# Processed batch 570 / 20000
# Processed batch 571 / 20000
# Processed batch 572 / 20000
# Processed batch 573 / 20000
# Processed batch 574 / 20000
# Processed batch 575 / 20000
# Processed batch 576 / 20000
# Processed batch 577 / 20000
# Processed batch 578 / 20000
# Processed batch 579 / 20000
# Processed batch 580 / 20000
# Processed batch 581 / 20000
# Processed batch 582 / 20000
# Processed batch 583 / 20000
# Processed batch 584 / 20000
# Processed batch 585 / 20000
# Processed batch 586 / 20000
# Processed batch 587 / 20000
# Processed batch 588 / 20000
# Processed batch 589 / 20000
# Processed batch 590 / 20000
# Processed batch 591 / 20000
# Processed batch 592 / 20000
# Processed batch 593 / 20000
# Processed batch 594 / 20000
# Processed batch 595 / 20000
# Processed batch 596 / 20000
# Processed batch 597 / 20000
# Processed batch 598 / 20000
# Processed batch 599 / 20000
# Processed batch 600 / 20000
# Processed batch 601 / 20000
# Processed batch 602 / 20000
# Processed batch 603 / 20000
# Processed batch 604 / 20000
# Processed batch 605 / 20000
# Processed batch 606 / 20000
# Processed batch 607 / 20000
# Processed batch 608 / 20000
# Processed batch 609 / 20000
# Processed batch 610 / 20000
# Processed batch 611 / 20000
# Processed batch 612 / 20000
# Processed batch 613 / 20000
# Processed batch 614 / 20000
# Processed batch 615 / 20000
# Processed batch 616 / 20000
# Processed batch 617 / 20000
# Processed batch 618 / 20000
# Processed batch 619 / 20000
# Processed batch 620 / 20000
# Processed batch 621 / 20000
# Processed batch 622 / 20000
# Processed batch 623 / 20000
# Processed batch 624 / 20000
# Processed batch 625 / 20000
# Processed batch 626 / 20000
# Processed batch 627 / 20000
# Processed batch 628 / 20000
# Processed batch 629 / 20000
# Processed batch 630 / 20000
# Processed batch 631 / 20000
# Processed batch 632 / 20000
# Processed batch 633 / 20000
# Processed batch 634 / 20000
# Processed batch 635 / 20000
# Processed batch 636 / 20000
# Processed batch 637 / 20000
# Processed batch 638 / 20000
# Processed batch 639 / 20000
# Processed batch 640 / 20000
# Processed batch 641 / 20000
# Processed batch 642 / 20000
# Processed batch 643 / 20000
# Processed batch 644 / 20000
# Processed batch 645 / 20000
# Processed batch 646 / 20000
# Processed batch 647 / 20000
# Processed batch 648 / 20000
# Processed batch 649 / 20000
# Processed batch 650 / 20000
# Processed batch 651 / 20000
# Processed batch 652 / 20000
# Processed batch 653 / 20000
# Processed batch 654 / 20000
# Processed batch 655 / 20000
# Processed batch 656 / 20000
# Processed batch 657 / 20000
# Processed batch 658 / 20000
# Processed batch 659 / 20000
# Processed batch 660 / 20000
# Processed batch 661 / 20000
# Processed batch 662 / 20000
# Processed batch 663 / 20000
# Processed batch 664 / 20000
# Processed batch 665 / 20000
# Processed batch 666 / 20000
# Processed batch 667 / 20000
# Processed batch 668 / 20000
# Processed batch 669 / 20000
# Processed batch 670 / 20000
# Processed batch 671 / 20000
# Processed batch 672 / 20000
# Processed batch 673 / 20000
# Processed batch 674 / 20000
# Processed batch 675 / 20000
# Processed batch 676 / 20000
# Processed batch 677 / 20000
# Processed batch 678 / 20000
# Processed batch 679 / 20000
# Processed batch 680 / 20000
# Processed batch 681 / 20000
# Processed batch 682 / 20000
# Processed batch 683 / 20000
# Processed batch 684 / 20000
# Processed batch 685 / 20000
# Processed batch 686 / 20000
# Processed batch 687 / 20000
# Processed batch 688 / 20000
# Processed batch 689 / 20000
# Processed batch 690 / 20000
# Processed batch 691 / 20000
# Processed batch 692 / 20000
# Processed batch 693 / 20000
# Processed batch 694 / 20000
# Processed batch 695 / 20000
# Processed batch 696 / 20000
# Processed batch 697 / 20000
# Processed batch 698 / 20000
# Processed batch 699 / 20000
# Processed batch 700 / 20000
# Processed batch 701 / 20000
# Processed batch 702 / 20000
# Processed batch 703 / 20000
# Processed batch 704 / 20000
# Processed batch 705 / 20000
# Processed batch 706 / 20000
# Processed batch 707 / 20000
# Processed batch 708 / 20000
# Processed batch 709 / 20000
# Processed batch 710 / 20000
# Processed batch 711 / 20000
# Processed batch 712 / 20000
# Processed batch 713 / 20000
# Processed batch 714 / 20000
# Processed batch 715 / 20000
# Processed batch 716 / 20000
# Processed batch 717 / 20000
# Processed batch 718 / 20000
# Processed batch 719 / 20000
# Processed batch 720 / 20000
# Processed batch 721 / 20000
# Processed batch 722 / 20000
# Processed batch 723 / 20000
# Processed batch 724 / 20000
# Processed batch 725 / 20000
# Processed batch 726 / 20000
# Processed batch 727 / 20000
# Processed batch 728 / 20000
# Processed batch 729 / 20000
# Processed batch 730 / 20000
# Processed batch 731 / 20000
# Processed batch 732 / 20000
# Processed batch 733 / 20000
# Processed batch 734 / 20000
# Processed batch 735 / 20000
# Processed batch 736 / 20000
# Processed batch 737 / 20000
# Processed batch 738 / 20000
# Processed batch 739 / 20000
# Processed batch 740 / 20000
# Processed batch 741 / 20000
# Processed batch 742 / 20000
# Processed batch 743 / 20000
# Processed batch 744 / 20000
# Processed batch 745 / 20000
# Processed batch 746 / 20000
# Processed batch 747 / 20000
# Processed batch 748 / 20000
# Processed batch 749 / 20000
# Processed batch 750 / 20000
# Processed batch 751 / 20000
# Processed batch 752 / 20000
# Processed batch 753 / 20000
# Processed batch 754 / 20000
# Processed batch 755 / 20000
# Processed batch 756 / 20000
# Processed batch 757 / 20000
# Processed batch 758 / 20000
# Processed batch 759 / 20000
# Processed batch 760 / 20000
# Processed batch 761 / 20000
# Processed batch 762 / 20000
# Processed batch 763 / 20000
# Processed batch 764 / 20000
# Processed batch 765 / 20000
# Processed batch 766 / 20000
# Processed batch 767 / 20000
# Processed batch 768 / 20000
# Processed batch 769 / 20000
# Processed batch 770 / 20000
# Processed batch 771 / 20000
# Processed batch 772 / 20000
# Processed batch 773 / 20000
# Processed batch 774 / 20000
# Processed batch 775 / 20000
# Processed batch 776 / 20000
# Processed batch 777 / 20000
# Processed batch 778 / 20000
# Processed batch 779 / 20000
# Processed batch 780 / 20000
# Processed batch 781 / 20000
# Processed batch 782 / 20000
# Processed batch 783 / 20000
# Processed batch 784 / 20000
# Processed batch 785 / 20000
# Processed batch 786 / 20000
# Processed batch 787 / 20000
# Processed batch 788 / 20000
# Processed batch 789 / 20000
# Processed batch 790 / 20000
# Processed batch 791 / 20000
# Processed batch 792 / 20000
# Processed batch 793 / 20000
# Processed batch 794 / 20000
# Processed batch 795 / 20000
# Processed batch 796 / 20000
# Processed batch 797 / 20000
# Processed batch 798 / 20000
# Processed batch 799 / 20000
# Processed batch 800 / 20000
# Processed batch 801 / 20000
# Processed batch 802 / 20000
# Processed batch 803 / 20000
# Processed batch 804 / 20000
# Processed batch 805 / 20000
# Processed batch 806 / 20000
# Processed batch 807 / 20000
# Processed batch 808 / 20000
# Processed batch 809 / 20000
# Processed batch 810 / 20000
# Processed batch 811 / 20000
# Processed batch 812 / 20000
# Processed batch 813 / 20000
# Processed batch 814 / 20000
# Processed batch 815 / 20000
# Processed batch 816 / 20000
# Processed batch 817 / 20000
# Processed batch 818 / 20000
# Processed batch 819 / 20000
# Processed batch 820 / 20000
# Processed batch 821 / 20000
# Processed batch 822 / 20000
# Processed batch 823 / 20000
# Processed batch 824 / 20000
# Processed batch 825 / 20000
# Processed batch 826 / 20000
# Processed batch 827 / 20000
# Processed batch 828 / 20000
# Processed batch 829 / 20000
# Processed batch 830 / 20000
# Processed batch 831 / 20000
# Processed batch 832 / 20000
# Processed batch 833 / 20000
# Processed batch 834 / 20000
# Processed batch 835 / 20000
# Processed batch 836 / 20000
# Processed batch 837 / 20000
# Processed batch 838 / 20000
# Processed batch 839 / 20000
# Processed batch 840 / 20000
# Processed batch 841 / 20000
# Processed batch 842 / 20000
# Processed batch 843 / 20000
# Processed batch 844 / 20000
# Processed batch 845 / 20000
# Processed batch 846 / 20000
# Processed batch 847 / 20000
# Processed batch 848 / 20000
# Processed batch 849 / 20000
# Processed batch 850 / 20000
# Processed batch 851 / 20000
# Processed batch 852 / 20000
# Processed batch 853 / 20000
# Processed batch 854 / 20000
# Processed batch 855 / 20000
# Processed batch 856 / 20000
# Processed batch 857 / 20000
# Processed batch 858 / 20000
# Processed batch 859 / 20000
# Processed batch 860 / 20000
# Processed batch 861 / 20000
# Processed batch 862 / 20000
# Processed batch 863 / 20000
# Processed batch 864 / 20000
# Processed batch 865 / 20000
# Processed batch 866 / 20000
# Processed batch 867 / 20000
# Processed batch 868 / 20000
# Processed batch 869 / 20000
# Processed batch 870 / 20000
# Processed batch 871 / 20000
# Processed batch 872 / 20000
# Processed batch 873 / 20000
# Processed batch 874 / 20000
# Processed batch 875 / 20000
# Processed batch 876 / 20000
# Processed batch 877 / 20000
# Processed batch 878 / 20000
# Processed batch 879 / 20000
# Processed batch 880 / 20000
# Processed batch 881 / 20000
# Processed batch 882 / 20000
# Processed batch 883 / 20000
# Processed batch 884 / 20000
# Processed batch 885 / 20000
# Processed batch 886 / 20000
# Processed batch 887 / 20000
# Processed batch 888 / 20000
# Processed batch 889 / 20000
# Processed batch 890 / 20000
# Processed batch 891 / 20000
# Processed batch 892 / 20000
# Processed batch 893 / 20000
# Processed batch 894 / 20000
# Processed batch 895 / 20000
# Processed batch 896 / 20000
# Processed batch 897 / 20000
# Processed batch 898 / 20000
# Processed batch 899 / 20000
# Processed batch 900 / 20000
# Processed batch 901 / 20000
# Processed batch 902 / 20000
# Processed batch 903 / 20000
# Processed batch 904 / 20000
# Processed batch 905 / 20000
# Processed batch 906 / 20000
# Processed batch 907 / 20000
# Processed batch 908 / 20000
# Processed batch 909 / 20000
# Processed batch 910 / 20000
# Processed batch 911 / 20000
# Processed batch 912 / 20000
# Processed batch 913 / 20000
# Processed batch 914 / 20000
# Processed batch 915 / 20000
# Processed batch 916 / 20000
# Processed batch 917 / 20000
# Processed batch 918 / 20000
# Processed batch 919 / 20000
# Processed batch 920 / 20000
# Processed batch 921 / 20000
# Processed batch 922 / 20000
# Processed batch 923 / 20000
# Processed batch 924 / 20000
# Processed batch 925 / 20000
# Processed batch 926 / 20000
# Processed batch 927 / 20000
# Processed batch 928 / 20000
# Processed batch 929 / 20000
# Processed batch 930 / 20000
# Processed batch 931 / 20000
# Processed batch 932 / 20000
# Processed batch 933 / 20000
# Processed batch 934 / 20000
# Processed batch 935 / 20000
# Processed batch 936 / 20000
# Processed batch 937 / 20000
# Processed batch 938 / 20000
# Processed batch 939 / 20000
# Processed batch 940 / 20000
# Processed batch 941 / 20000
# Processed batch 942 / 20000
# Processed batch 943 / 20000
# Processed batch 944 / 20000
# Processed batch 945 / 20000
# Processed batch 946 / 20000
# Processed batch 947 / 20000
# Processed batch 948 / 20000
# Processed batch 949 / 20000
# Processed batch 950 / 20000
# Processed batch 951 / 20000
# Processed batch 952 / 20000
# Processed batch 953 / 20000
# Processed batch 954 / 20000
# Processed batch 955 / 20000
# Processed batch 956 / 20000
# Processed batch 957 / 20000
# Processed batch 958 / 20000
# Processed batch 959 / 20000
# Processed batch 960 / 20000
# Processed batch 961 / 20000
# Processed batch 962 / 20000
# Processed batch 963 / 20000
# Processed batch 964 / 20000
# Processed batch 965 / 20000
# Processed batch 966 / 20000
# Processed batch 967 / 20000
# Processed batch 968 / 20000
# Processed batch 969 / 20000
# Processed batch 970 / 20000
# Processed batch 971 / 20000
# Processed batch 972 / 20000
# Processed batch 973 / 20000
# Processed batch 974 / 20000
# Processed batch 975 / 20000
# Processed batch 976 / 20000
# Processed batch 977 / 20000
# Processed batch 978 / 20000
# Processed batch 979 / 20000
# Processed batch 980 / 20000
# Processed batch 981 / 20000
# Processed batch 982 / 20000
# Processed batch 983 / 20000
# Processed batch 984 / 20000
# Processed batch 985 / 20000
# Processed batch 986 / 20000
# Processed batch 987 / 20000
# Processed batch 988 / 20000
# Processed batch 989 / 20000
# Processed batch 990 / 20000
# Processed batch 991 / 20000
# Processed batch 992 / 20000
# Processed batch 993 / 20000
# Processed batch 994 / 20000
# Processed batch 995 / 20000
# Processed batch 996 / 20000
# Processed batch 997 / 20000
# Processed batch 998 / 20000
# Processed batch 999 / 20000
# Processed batch 1000 / 20000
# Processed batch 1001 / 20000
# Processed batch 1002 / 20000
# Processed batch 1003 / 20000
# Processed batch 1004 / 20000
# Processed batch 1005 / 20000
# Processed batch 1006 / 20000
# Processed batch 1007 / 20000
# Processed batch 1008 / 20000
# Processed batch 1009 / 20000
# Processed batch 1010 / 20000
# Processed batch 1011 / 20000
# Processed batch 1012 / 20000
# Processed batch 1013 / 20000
# Processed batch 1014 / 20000
# Processed batch 1015 / 20000
# Processed batch 1016 / 20000
# Processed batch 1017 / 20000
# Processed batch 1018 / 20000
# Processed batch 1019 / 20000
# Processed batch 1020 / 20000
# Processed batch 1021 / 20000
# Processed batch 1022 / 20000
# Processed batch 1023 / 20000
# Processed batch 1024 / 20000
# Processed batch 1025 / 20000
# Processed batch 1026 / 20000
# Processed batch 1027 / 20000
# Processed batch 1028 / 20000
# Processed batch 1029 / 20000
# Processed batch 1030 / 20000
# Processed batch 1031 / 20000
# Processed batch 1032 / 20000
# Processed batch 1033 / 20000
# Processed batch 1034 / 20000
# Processed batch 1035 / 20000
# Processed batch 1036 / 20000
# Processed batch 1037 / 20000
# Processed batch 1038 / 20000
# Processed batch 1039 / 20000
# Processed batch 1040 / 20000
# Processed batch 1041 / 20000
# Processed batch 1042 / 20000
# Processed batch 1043 / 20000
# Processed batch 1044 / 20000
# Processed batch 1045 / 20000
# Processed batch 1046 / 20000
# Processed batch 1047 / 20000
# Processed batch 1048 / 20000
# Processed batch 1049 / 20000
# Processed batch 1050 / 20000
# Processed batch 1051 / 20000
# Processed batch 1052 / 20000
# Processed batch 1053 / 20000
# Processed batch 1054 / 20000
# Processed batch 1055 / 20000
# Processed batch 1056 / 20000
# Processed batch 1057 / 20000
# Processed batch 1058 / 20000
# Processed batch 1059 / 20000
# Processed batch 1060 / 20000
# Processed batch 1061 / 20000
# Processed batch 1062 / 20000
# Processed batch 1063 / 20000
# Processed batch 1064 / 20000
# Processed batch 1065 / 20000
# Processed batch 1066 / 20000
# Processed batch 1067 / 20000
# Processed batch 1068 / 20000
# Processed batch 1069 / 20000
# Processed batch 1070 / 20000
# Processed batch 1071 / 20000
# Processed batch 1072 / 20000
# Processed batch 1073 / 20000
# Processed batch 1074 / 20000
# Processed batch 1075 / 20000
# Processed batch 1076 / 20000
# Processed batch 1077 / 20000
# Processed batch 1078 / 20000
# Processed batch 1079 / 20000
# Processed batch 1080 / 20000
# Processed batch 1081 / 20000
# Processed batch 1082 / 20000
# Processed batch 1083 / 20000
# Processed batch 1084 / 20000
# Processed batch 1085 / 20000
# Processed batch 1086 / 20000
# Processed batch 1087 / 20000
# Processed batch 1088 / 20000
# Processed batch 1089 / 20000
# Processed batch 1090 / 20000
# Processed batch 1091 / 20000
# Processed batch 1092 / 20000
# Processed batch 1093 / 20000
# Processed batch 1094 / 20000
# Processed batch 1095 / 20000
# Processed batch 1096 / 20000
# Processed batch 1097 / 20000
# Processed batch 1098 / 20000
# Processed batch 1099 / 20000
# Processed batch 1100 / 20000
# Processed batch 1101 / 20000
# Processed batch 1102 / 20000
# Processed batch 1103 / 20000
# Processed batch 1104 / 20000
# Processed batch 1105 / 20000
# Processed batch 1106 / 20000
# Processed batch 1107 / 20000
# Processed batch 1108 / 20000
# Processed batch 1109 / 20000
# Processed batch 1110 / 20000
# Processed batch 1111 / 20000
# Processed batch 1112 / 20000
# Processed batch 1113 / 20000
# Processed batch 1114 / 20000
# Processed batch 1115 / 20000
# Processed batch 1116 / 20000
# Processed batch 1117 / 20000
# Processed batch 1118 / 20000
# Processed batch 1119 / 20000
# Processed batch 1120 / 20000
# Processed batch 1121 / 20000
# Processed batch 1122 / 20000
# Processed batch 1123 / 20000
# Processed batch 1124 / 20000
# Processed batch 1125 / 20000
# Processed batch 1126 / 20000
# Processed batch 1127 / 20000
# Processed batch 1128 / 20000
# Processed batch 1129 / 20000
# Processed batch 1130 / 20000
# Processed batch 1131 / 20000
# Processed batch 1132 / 20000
# Processed batch 1133 / 20000
# Processed batch 1134 / 20000
# Processed batch 1135 / 20000
# Processed batch 1136 / 20000
# Processed batch 1137 / 20000
# Processed batch 1138 / 20000
# Processed batch 1139 / 20000
# Processed batch 1140 / 20000
# Processed batch 1141 / 20000
# Processed batch 1142 / 20000
# Processed batch 1143 / 20000
# Processed batch 1144 / 20000
# Processed batch 1145 / 20000
# Processed batch 1146 / 20000
# Processed batch 1147 / 20000
# Processed batch 1148 / 20000
# Processed batch 1149 / 20000
# Processed batch 1150 / 20000
# Processed batch 1151 / 20000
# Processed batch 1152 / 20000
# Processed batch 1153 / 20000
# Processed batch 1154 / 20000
# Processed batch 1155 / 20000
# Processed batch 1156 / 20000
# Processed batch 1157 / 20000
# Processed batch 1158 / 20000
# Processed batch 1159 / 20000
# Processed batch 1160 / 20000
# Processed batch 1161 / 20000
# Processed batch 1162 / 20000
# Processed batch 1163 / 20000
# Processed batch 1164 / 20000
# Processed batch 1165 / 20000
# Processed batch 1166 / 20000
# Processed batch 1167 / 20000
# Processed batch 1168 / 20000
# Processed batch 1169 / 20000
# Processed batch 1170 / 20000
# Processed batch 1171 / 20000
# Processed batch 1172 / 20000
# Processed batch 1173 / 20000
# Processed batch 1174 / 20000
# Processed batch 1175 / 20000
# Processed batch 1176 / 20000
# Processed batch 1177 / 20000
# Processed batch 1178 / 20000
# Processed batch 1179 / 20000
# Processed batch 1180 / 20000
# Processed batch 1181 / 20000
# Processed batch 1182 / 20000
# Processed batch 1183 / 20000
# Processed batch 1184 / 20000
# Processed batch 1185 / 20000
# Processed batch 1186 / 20000
# Processed batch 1187 / 20000
# Processed batch 1188 / 20000
# Processed batch 1189 / 20000
# Processed batch 1190 / 20000
# Processed batch 1191 / 20000
# Processed batch 1192 / 20000
# Processed batch 1193 / 20000
# Processed batch 1194 / 20000
# Processed batch 1195 / 20000
# Processed batch 1196 / 20000
# Processed batch 1197 / 20000
# Processed batch 1198 / 20000
# Processed batch 1199 / 20000
# Processed batch 1200 / 20000
# Processed batch 1201 / 20000
# Processed batch 1202 / 20000
# Processed batch 1203 / 20000
# Processed batch 1204 / 20000
# Processed batch 1205 / 20000
# Processed batch 1206 / 20000
# Processed batch 1207 / 20000
# Processed batch 1208 / 20000
# Processed batch 1209 / 20000
# Processed batch 1210 / 20000
# Processed batch 1211 / 20000
# Processed batch 1212 / 20000
# Processed batch 1213 / 20000
# Processed batch 1214 / 20000
# Processed batch 1215 / 20000
# Processed batch 1216 / 20000
# Processed batch 1217 / 20000
# Processed batch 1218 / 20000
# Processed batch 1219 / 20000
# Processed batch 1220 / 20000
# Processed batch 1221 / 20000
# Processed batch 1222 / 20000
# Processed batch 1223 / 20000
# Processed batch 1224 / 20000
# Processed batch 1225 / 20000
# Processed batch 1226 / 20000
# Processed batch 1227 / 20000
# Processed batch 1228 / 20000
# Processed batch 1229 / 20000
# Processed batch 1230 / 20000
# Processed batch 1231 / 20000
# Processed batch 1232 / 20000
# Processed batch 1233 / 20000
# Processed batch 1234 / 20000
# Processed batch 1235 / 20000
# Processed batch 1236 / 20000
# Processed batch 1237 / 20000
# Processed batch 1238 / 20000
# Processed batch 1239 / 20000
# Processed batch 1240 / 20000
# Processed batch 1241 / 20000
# Processed batch 1242 / 20000
# Processed batch 1243 / 20000
# Processed batch 1244 / 20000
# Processed batch 1245 / 20000
# Processed batch 1246 / 20000
# Processed batch 1247 / 20000
# Processed batch 1248 / 20000
# Processed batch 1249 / 20000
# Processed batch 1250 / 20000
# Processed batch 1251 / 20000
# Processed batch 1252 / 20000
# Processed batch 1253 / 20000
# Processed batch 1254 / 20000
# Processed batch 1255 / 20000
# Processed batch 1256 / 20000
# Processed batch 1257 / 20000
# Processed batch 1258 / 20000
# Processed batch 1259 / 20000
# Processed batch 1260 / 20000
# Processed batch 1261 / 20000
# Processed batch 1262 / 20000
# Processed batch 1263 / 20000
# Processed batch 1264 / 20000
# Processed batch 1265 / 20000
# Processed batch 1266 / 20000
# Processed batch 1267 / 20000
# Processed batch 1268 / 20000
# Processed batch 1269 / 20000
# Processed batch 1270 / 20000
# Processed batch 1271 / 20000
# Processed batch 1272 / 20000
# Processed batch 1273 / 20000
# Processed batch 1274 / 20000
# Processed batch 1275 / 20000
# Processed batch 1276 / 20000
# Processed batch 1277 / 20000
# Processed batch 1278 / 20000
# Processed batch 1279 / 20000
# Processed batch 1280 / 20000
# Processed batch 1281 / 20000
# Processed batch 1282 / 20000
# Processed batch 1283 / 20000
# Processed batch 1284 / 20000
# Processed batch 1285 / 20000
# Processed batch 1286 / 20000
# Processed batch 1287 / 20000
# Processed batch 1288 / 20000
# Processed batch 1289 / 20000
# Processed batch 1290 / 20000
# Processed batch 1291 / 20000
# Processed batch 1292 / 20000
# Processed batch 1293 / 20000
# Processed batch 1294 / 20000
# Processed batch 1295 / 20000
# Processed batch 1296 / 20000
# Processed batch 1297 / 20000
# Processed batch 1298 / 20000
# Processed batch 1299 / 20000
# Processed batch 1300 / 20000
# Processed batch 1301 / 20000
# Processed batch 1302 / 20000
# Processed batch 1303 / 20000
# Processed batch 1304 / 20000
# Processed batch 1305 / 20000
# Processed batch 1306 / 20000
# Processed batch 1307 / 20000
# Processed batch 1308 / 20000
# Processed batch 1309 / 20000
# Processed batch 1310 / 20000
# Processed batch 1311 / 20000
# Processed batch 1312 / 20000
# Processed batch 1313 / 20000
# Processed batch 1314 / 20000
# Processed batch 1315 / 20000
# Processed batch 1316 / 20000
# Processed batch 1317 / 20000
# Processed batch 1318 / 20000
# Processed batch 1319 / 20000
# Processed batch 1320 / 20000
# Processed batch 1321 / 20000
# Processed batch 1322 / 20000
# Processed batch 1323 / 20000
# Processed batch 1324 / 20000
# Processed batch 1325 / 20000
# Processed batch 1326 / 20000
# Processed batch 1327 / 20000
# Processed batch 1328 / 20000
# Processed batch 1329 / 20000
# Processed batch 1330 / 20000
# Processed batch 1331 / 20000
# Processed batch 1332 / 20000
# Processed batch 1333 / 20000
# Processed batch 1334 / 20000
# Processed batch 1335 / 20000
# Processed batch 1336 / 20000
# Processed batch 1337 / 20000
# Processed batch 1338 / 20000
# Processed batch 1339 / 20000
# Processed batch 1340 / 20000
# Processed batch 1341 / 20000
# Processed batch 1342 / 20000
# Processed batch 1343 / 20000
# Processed batch 1344 / 20000
# Processed batch 1345 / 20000
# Processed batch 1346 / 20000
# Processed batch 1347 / 20000
# Processed batch 1348 / 20000
# Processed batch 1349 / 20000
# Processed batch 1350 / 20000
# Processed batch 1351 / 20000
# Processed batch 1352 / 20000
# Processed batch 1353 / 20000
# Processed batch 1354 / 20000
# Processed batch 1355 / 20000
# Processed batch 1356 / 20000
# Processed batch 1357 / 20000
# Processed batch 1358 / 20000
# Processed batch 1359 / 20000
# Processed batch 1360 / 20000
# Processed batch 1361 / 20000
# Processed batch 1362 / 20000
# Processed batch 1363 / 20000
# Processed batch 1364 / 20000
# Processed batch 1365 / 20000
# Processed batch 1366 / 20000
# Processed batch 1367 / 20000
# Processed batch 1368 / 20000
# Processed batch 1369 / 20000
# Processed batch 1370 / 20000
# Processed batch 1371 / 20000
# Processed batch 1372 / 20000
# Processed batch 1373 / 20000
# Processed batch 1374 / 20000
# Processed batch 1375 / 20000
# Processed batch 1376 / 20000
# Processed batch 1377 / 20000
# Processed batch 1378 / 20000
# Processed batch 1379 / 20000
# Processed batch 1380 / 20000
# Processed batch 1381 / 20000
# Processed batch 1382 / 20000
# Processed batch 1383 / 20000
# Processed batch 1384 / 20000
# Processed batch 1385 / 20000
# Processed batch 1386 / 20000
# Processed batch 1387 / 20000
# Processed batch 1388 / 20000
# Processed batch 1389 / 20000
# Processed batch 1390 / 20000
# Processed batch 1391 / 20000
# Processed batch 1392 / 20000
# Processed batch 1393 / 20000
# Processed batch 1394 / 20000
# Processed batch 1395 / 20000
# Processed batch 1396 / 20000
# Processed batch 1397 / 20000
# Processed batch 1398 / 20000
# Processed batch 1399 / 20000
# Processed batch 1400 / 20000
# Processed batch 1401 / 20000
# Processed batch 1402 / 20000
# Processed batch 1403 / 20000
# Processed batch 1404 / 20000
# Processed batch 1405 / 20000
# Processed batch 1406 / 20000
# Processed batch 1407 / 20000
# Processed batch 1408 / 20000
# Processed batch 1409 / 20000
# Processed batch 1410 / 20000
# Processed batch 1411 / 20000
# Processed batch 1412 / 20000
# Processed batch 1413 / 20000
# Processed batch 1414 / 20000
# Processed batch 1415 / 20000
# Processed batch 1416 / 20000
# Processed batch 1417 / 20000
# Processed batch 1418 / 20000
# Processed batch 1419 / 20000
# Processed batch 1420 / 20000
# Processed batch 1421 / 20000
# Processed batch 1422 / 20000
# Processed batch 1423 / 20000
# Processed batch 1424 / 20000
# Processed batch 1425 / 20000
# Processed batch 1426 / 20000
# Processed batch 1427 / 20000
# Processed batch 1428 / 20000
# Processed batch 1429 / 20000
# Processed batch 1430 / 20000
# Processed batch 1431 / 20000
# Processed batch 1432 / 20000
# Processed batch 1433 / 20000
# Processed batch 1434 / 20000
# Processed batch 1435 / 20000
# Processed batch 1436 / 20000
# Processed batch 1437 / 20000
# Processed batch 1438 / 20000
# Processed batch 1439 / 20000
# Processed batch 1440 / 20000
# Processed batch 1441 / 20000
# Processed batch 1442 / 20000
# Processed batch 1443 / 20000
# Processed batch 1444 / 20000
# Processed batch 1445 / 20000
# Processed batch 1446 / 20000
# Processed batch 1447 / 20000
# Processed batch 1448 / 20000
# Processed batch 1449 / 20000
# Processed batch 1450 / 20000
# Processed batch 1451 / 20000
# Processed batch 1452 / 20000
# Processed batch 1453 / 20000
# Processed batch 1454 / 20000
# Processed batch 1455 / 20000
# Processed batch 1456 / 20000
# Processed batch 1457 / 20000
# Processed batch 1458 / 20000
# Processed batch 1459 / 20000
# Processed batch 1460 / 20000
# Processed batch 1461 / 20000
# Processed batch 1462 / 20000
# Processed batch 1463 / 20000
# Processed batch 1464 / 20000
# Processed batch 1465 / 20000
# Processed batch 1466 / 20000
# Processed batch 1467 / 20000
# Processed batch 1468 / 20000
# Processed batch 1469 / 20000
# Processed batch 1470 / 20000
# Processed batch 1471 / 20000
# Processed batch 1472 / 20000
# Processed batch 1473 / 20000
# Processed batch 1474 / 20000
# Processed batch 1475 / 20000
# Processed batch 1476 / 20000
# Processed batch 1477 / 20000
# Processed batch 1478 / 20000
# Processed batch 1479 / 20000
# Processed batch 1480 / 20000
# Processed batch 1481 / 20000
# Processed batch 1482 / 20000
# Processed batch 1483 / 20000
# Processed batch 1484 / 20000
# Processed batch 1485 / 20000
# Processed batch 1486 / 20000
# Processed batch 1487 / 20000
# Processed batch 1488 / 20000
# Processed batch 1489 / 20000
# Processed batch 1490 / 20000
# Processed batch 1491 / 20000
# Processed batch 1492 / 20000
# Processed batch 1493 / 20000
# Processed batch 1494 / 20000
# Processed batch 1495 / 20000
# Processed batch 1496 / 20000
# Processed batch 1497 / 20000
# Processed batch 1498 / 20000
# Processed batch 1499 / 20000
# Processed batch 1500 / 20000
# Processed batch 1501 / 20000
# Processed batch 1502 / 20000
# Processed batch 1503 / 20000
# Processed batch 1504 / 20000
# Processed batch 1505 / 20000
# Processed batch 1506 / 20000
# Processed batch 1507 / 20000
# Processed batch 1508 / 20000
# Processed batch 1509 / 20000
# Processed batch 1510 / 20000
# Processed batch 1511 / 20000
# Processed batch 1512 / 20000
# Processed batch 1513 / 20000
# Processed batch 1514 / 20000
# Processed batch 1515 / 20000
# Processed batch 1516 / 20000
# Processed batch 1517 / 20000
# Processed batch 1518 / 20000
# Processed batch 1519 / 20000
# Processed batch 1520 / 20000
# Processed batch 1521 / 20000
# Processed batch 1522 / 20000
# Processed batch 1523 / 20000
# Processed batch 1524 / 20000
# Processed batch 1525 / 20000
# Processed batch 1526 / 20000
# Processed batch 1527 / 20000
# Processed batch 1528 / 20000
# Processed batch 1529 / 20000
# Processed batch 1530 / 20000
# Processed batch 1531 / 20000
# Processed batch 1532 / 20000
# Processed batch 1533 / 20000
# Processed batch 1534 / 20000
# Processed batch 1535 / 20000
# Processed batch 1536 / 20000
# Processed batch 1537 / 20000
# Processed batch 1538 / 20000
# Processed batch 1539 / 20000
# Processed batch 1540 / 20000
# Processed batch 1541 / 20000
# Processed batch 1542 / 20000
# Processed batch 1543 / 20000
# Processed batch 1544 / 20000
# Processed batch 1545 / 20000
# Processed batch 1546 / 20000
# Processed batch 1547 / 20000
# Processed batch 1548 / 20000
# Processed batch 1549 / 20000
# Processed batch 1550 / 20000
# Processed batch 1551 / 20000
# Processed batch 1552 / 20000
# Processed batch 1553 / 20000
# Processed batch 1554 / 20000
# Processed batch 1555 / 20000
# Processed batch 1556 / 20000
# Processed batch 1557 / 20000
# Processed batch 1558 / 20000
# Processed batch 1559 / 20000
# Processed batch 1560 / 20000
# Processed batch 1561 / 20000
# Processed batch 1562 / 20000
# Processed batch 1563 / 20000
# Processed batch 1564 / 20000
# Processed batch 1565 / 20000
# Processed batch 1566 / 20000
# Processed batch 1567 / 20000
# Processed batch 1568 / 20000
# Processed batch 1569 / 20000
# Processed batch 1570 / 20000
# Processed batch 1571 / 20000
# Processed batch 1572 / 20000
# Processed batch 1573 / 20000
# Processed batch 1574 / 20000
# Processed batch 1575 / 20000
# Processed batch 1576 / 20000
# Processed batch 1577 / 20000
# Processed batch 1578 / 20000
# Processed batch 1579 / 20000
# Processed batch 1580 / 20000
# Processed batch 1581 / 20000
# Processed batch 1582 / 20000
# Processed batch 1583 / 20000
# Processed batch 1584 / 20000
# Processed batch 1585 / 20000
# Processed batch 1586 / 20000
# Processed batch 1587 / 20000
# Processed batch 1588 / 20000
# Processed batch 1589 / 20000
# Processed batch 1590 / 20000
# Processed batch 1591 / 20000
# Processed batch 1592 / 20000
# Processed batch 1593 / 20000
# Processed batch 1594 / 20000
# Processed batch 1595 / 20000
# Processed batch 1596 / 20000
# Processed batch 1597 / 20000
# Processed batch 1598 / 20000
# Processed batch 1599 / 20000
# Processed batch 1600 / 20000
# Processed batch 1601 / 20000
# Processed batch 1602 / 20000
# Processed batch 1603 / 20000
# Processed batch 1604 / 20000
# Processed batch 1605 / 20000
# Processed batch 1606 / 20000
# Processed batch 1607 / 20000
# Processed batch 1608 / 20000
# Processed batch 1609 / 20000
# Processed batch 1610 / 20000
# Processed batch 1611 / 20000
# Processed batch 1612 / 20000
# Processed batch 1613 / 20000
# Processed batch 1614 / 20000
# Processed batch 1615 / 20000
# Processed batch 1616 / 20000
# Processed batch 1617 / 20000
# Processed batch 1618 / 20000
# Processed batch 1619 / 20000
# Processed batch 1620 / 20000
# Processed batch 1621 / 20000
# Processed batch 1622 / 20000
# Processed batch 1623 / 20000
# Processed batch 1624 / 20000
# Processed batch 1625 / 20000
# Processed batch 1626 / 20000
# Processed batch 1627 / 20000
# Processed batch 1628 / 20000
# Processed batch 1629 / 20000
# Processed batch 1630 / 20000
# Processed batch 1631 / 20000
# Processed batch 1632 / 20000
# Processed batch 1633 / 20000
# Processed batch 1634 / 20000
# Processed batch 1635 / 20000
# Processed batch 1636 / 20000
# Processed batch 1637 / 20000
# Processed batch 1638 / 20000
# Processed batch 1639 / 20000
# Processed batch 1640 / 20000
# Processed batch 1641 / 20000
# Processed batch 1642 / 20000
# Processed batch 1643 / 20000
# Processed batch 1644 / 20000
# Processed batch 1645 / 20000
# Processed batch 1646 / 20000
# Processed batch 1647 / 20000
# Processed batch 1648 / 20000
# Processed batch 1649 / 20000
# Processed batch 1650 / 20000
# Processed batch 1651 / 20000
# Processed batch 1652 / 20000
# Processed batch 1653 / 20000
# Processed batch 1654 / 20000
# Processed batch 1655 / 20000
# Processed batch 1656 / 20000
# Processed batch 1657 / 20000
# Processed batch 1658 / 20000
# Processed batch 1659 / 20000
# Processed batch 1660 / 20000
# Processed batch 1661 / 20000
# Processed batch 1662 / 20000
# Processed batch 1663 / 20000
# Processed batch 1664 / 20000
# Processed batch 1665 / 20000
# Processed batch 1666 / 20000
# Processed batch 1667 / 20000
# Processed batch 1668 / 20000
# Processed batch 1669 / 20000
# Processed batch 1670 / 20000
# Processed batch 1671 / 20000
# Processed batch 1672 / 20000
# Processed batch 1673 / 20000
# Processed batch 1674 / 20000
# Processed batch 1675 / 20000
# Processed batch 1676 / 20000
# Processed batch 1677 / 20000
# Processed batch 1678 / 20000
# Processed batch 1679 / 20000
# Processed batch 1680 / 20000
# Processed batch 1681 / 20000
# Processed batch 1682 / 20000
# Processed batch 1683 / 20000
# Processed batch 1684 / 20000
# Processed batch 1685 / 20000
# Processed batch 1686 / 20000
# Processed batch 1687 / 20000
# Processed batch 1688 / 20000
# Processed batch 1689 / 20000
# Processed batch 1690 / 20000
# Processed batch 1691 / 20000
# Processed batch 1692 / 20000
# Processed batch 1693 / 20000
# ...
# Processed batch 19468 / 20000
# Processed batch 19469 / 20000
# Processed batch 19470 / 20000
# Processed batch 19471 / 20000
# Processed batch 19472 / 20000
# Processed batch 19473 / 20000
# Processed batch 19474 / 20000
# Processed batch 19475 / 20000
# Processed batch 19476 / 20000
# Processed batch 19477 / 20000
# Processed batch 19478 / 20000
# Processed batch 19479 / 20000
# Processed batch 19480 / 20000
# Processed batch 19481 / 20000
# Processed batch 19482 / 20000
# Processed batch 19483 / 20000
# Processed batch 19484 / 20000
# Processed batch 19485 / 20000
# Processed batch 19486 / 20000
# Processed batch 19487 / 20000
# Processed batch 19488 / 20000
# Processed batch 19489 / 20000
# Processed batch 19490 / 20000
# Processed batch 19491 / 20000
# Processed batch 19492 / 20000
# Processed batch 19493 / 20000
# Processed batch 19494 / 20000
# Processed batch 19495 / 20000
# Processed batch 19496 / 20000
# Processed batch 19497 / 20000
# Processed batch 19498 / 20000
# Processed batch 19499 / 20000
# Processed batch 19500 / 20000
# Processed batch 19501 / 20000
# Processed batch 19502 / 20000
# Processed batch 19503 / 20000
# Processed batch 19504 / 20000
# Processed batch 19505 / 20000
# Processed batch 19506 / 20000
# Processed batch 19507 / 20000
# Processed batch 19508 / 20000
# Processed batch 19509 / 20000
# Processed batch 19510 / 20000
# Processed batch 19511 / 20000
# Processed batch 19512 / 20000
# Processed batch 19513 / 20000
# Processed batch 19514 / 20000
# Processed batch 19515 / 20000
# Processed batch 19516 / 20000
# Processed batch 19517 / 20000
# Processed batch 19518 / 20000
# Processed batch 19519 / 20000
# Processed batch 19520 / 20000
# Processed batch 19521 / 20000
# Processed batch 19522 / 20000
# Processed batch 19523 / 20000
# Processed batch 19524 / 20000
# Processed batch 19525 / 20000
# Processed batch 19526 / 20000
# Processed batch 19527 / 20000
# Processed batch 19528 / 20000
# Processed batch 19529 / 20000
# Processed batch 19530 / 20000
# Processed batch 19531 / 20000
# Processed batch 19532 / 20000
# Processed batch 19533 / 20000
# Processed batch 19534 / 20000
# Processed batch 19535 / 20000
# Processed batch 19536 / 20000
# Processed batch 19537 / 20000
# Processed batch 19538 / 20000
# Processed batch 19539 / 20000
# Processed batch 19540 / 20000
# Processed batch 19541 / 20000
# Processed batch 19542 / 20000
# Processed batch 19543 / 20000
# Processed batch 19544 / 20000
# Processed batch 19545 / 20000
# Processed batch 19546 / 20000
# Processed batch 19547 / 20000
# Processed batch 19548 / 20000
# Processed batch 19549 / 20000
# Processed batch 19550 / 20000
# Processed batch 19551 / 20000
# Processed batch 19552 / 20000
# Processed batch 19553 / 20000
# Processed batch 19554 / 20000
# Processed batch 19555 / 20000
# Processed batch 19556 / 20000
# Processed batch 19557 / 20000
# Processed batch 19558 / 20000
# Processed batch 19559 / 20000
# Processed batch 19560 / 20000
# Processed batch 19561 / 20000
# Processed batch 19562 / 20000
# Processed batch 19563 / 20000
# Processed batch 19564 / 20000
# Processed batch 19565 / 20000
# Processed batch 19566 / 20000
# Processed batch 19567 / 20000
# Processed batch 19568 / 20000
# Processed batch 19569 / 20000
# Processed batch 19570 / 20000
# Processed batch 19571 / 20000
# Processed batch 19572 / 20000
# Processed batch 19573 / 20000
# Processed batch 19574 / 20000
# Processed batch 19575 / 20000
# Processed batch 19576 / 20000
# Processed batch 19577 / 20000
# Processed batch 19578 / 20000
# Processed batch 19579 / 20000
# Processed batch 19580 / 20000
# Processed batch 19581 / 20000
# Processed batch 19582 / 20000
# Processed batch 19583 / 20000
# Processed batch 19584 / 20000
# Processed batch 19585 / 20000
# Processed batch 19586 / 20000
# Processed batch 19587 / 20000
# Processed batch 19588 / 20000
# Processed batch 19589 / 20000
# Processed batch 19590 / 20000
# Processed batch 19591 / 20000
# Processed batch 19592 / 20000
# Processed batch 19593 / 20000
# Processed batch 19594 / 20000
# Processed batch 19595 / 20000
# Processed batch 19596 / 20000
# Processed batch 19597 / 20000
# Processed batch 19598 / 20000
# Processed batch 19599 / 20000
# Processed batch 19600 / 20000
# Processed batch 19601 / 20000
# Processed batch 19602 / 20000
# Processed batch 19603 / 20000
# Processed batch 19604 / 20000
# Processed batch 19605 / 20000
# Processed batch 19606 / 20000
# Processed batch 19607 / 20000
# Processed batch 19608 / 20000
# Processed batch 19609 / 20000
# Processed batch 19610 / 20000
# Processed batch 19611 / 20000
# Processed batch 19612 / 20000
# Processed batch 19613 / 20000
# Processed batch 19614 / 20000
# Processed batch 19615 / 20000
# Processed batch 19616 / 20000
# Processed batch 19617 / 20000
# Processed batch 19618 / 20000
# Processed batch 19619 / 20000
# Processed batch 19620 / 20000
# Processed batch 19621 / 20000
# Processed batch 19622 / 20000
# Processed batch 19623 / 20000
# Processed batch 19624 / 20000
# Processed batch 19625 / 20000
# Processed batch 19626 / 20000
# Processed batch 19627 / 20000
# Processed batch 19628 / 20000
# Processed batch 19629 / 20000
# Processed batch 19630 / 20000
# Processed batch 19631 / 20000
# Processed batch 19632 / 20000
# Processed batch 19633 / 20000
# Processed batch 19634 / 20000
# Processed batch 19635 / 20000
# Processed batch 19636 / 20000
# Processed batch 19637 / 20000
# Processed batch 19638 / 20000
# Processed batch 19639 / 20000
# Processed batch 19640 / 20000
# Processed batch 19641 / 20000
# Processed batch 19642 / 20000
# Processed batch 19643 / 20000
# Processed batch 19644 / 20000
# Processed batch 19645 / 20000
# Processed batch 19646 / 20000
# Processed batch 19647 / 20000
# Processed batch 19648 / 20000
# Processed batch 19649 / 20000
# Processed batch 19650 / 20000
# Processed batch 19651 / 20000
# Processed batch 19652 / 20000
# Processed batch 19653 / 20000
# Processed batch 19654 / 20000
# Processed batch 19655 / 20000
# Processed batch 19656 / 20000
# Processed batch 19657 / 20000
# Processed batch 19658 / 20000
# Processed batch 19659 / 20000
# Processed batch 19660 / 20000
# Processed batch 19661 / 20000
# Processed batch 19662 / 20000
# Processed batch 19663 / 20000
# Processed batch 19664 / 20000
# Processed batch 19665 / 20000
# Processed batch 19666 / 20000
# Processed batch 19667 / 20000
# Processed batch 19668 / 20000
# Processed batch 19669 / 20000
# Processed batch 19670 / 20000
# Processed batch 19671 / 20000
# Processed batch 19672 / 20000
# Processed batch 19673 / 20000
# Processed batch 19674 / 20000
# Processed batch 19675 / 20000
# Processed batch 19676 / 20000
# Processed batch 19677 / 20000
# Processed batch 19678 / 20000
# Processed batch 19679 / 20000
# Processed batch 19680 / 20000
# Processed batch 19681 / 20000
# Processed batch 19682 / 20000
# Processed batch 19683 / 20000
# Processed batch 19684 / 20000
# Processed batch 19685 / 20000
# Processed batch 19686 / 20000
# Processed batch 19687 / 20000
# Processed batch 19688 / 20000
# Processed batch 19689 / 20000
# Processed batch 19690 / 20000
# Processed batch 19691 / 20000
# Processed batch 19692 / 20000
# Processed batch 19693 / 20000
# Processed batch 19694 / 20000
# Processed batch 19695 / 20000
# Processed batch 19696 / 20000
# Processed batch 19697 / 20000
# Processed batch 19698 / 20000
# Processed batch 19699 / 20000
# Processed batch 19700 / 20000
# Processed batch 19701 / 20000
# Processed batch 19702 / 20000
# Processed batch 19703 / 20000
# Processed batch 19704 / 20000
# Processed batch 19705 / 20000
# Processed batch 19706 / 20000
# Processed batch 19707 / 20000
# Processed batch 19708 / 20000
# Processed batch 19709 / 20000
# Processed batch 19710 / 20000
# Processed batch 19711 / 20000
# Processed batch 19712 / 20000
# Processed batch 19713 / 20000
# Processed batch 19714 / 20000
# Processed batch 19715 / 20000
# Processed batch 19716 / 20000
# Processed batch 19717 / 20000
# Processed batch 19718 / 20000
# Processed batch 19719 / 20000
# Processed batch 19720 / 20000
# Processed batch 19721 / 20000
# Processed batch 19722 / 20000
# Processed batch 19723 / 20000
# Processed batch 19724 / 20000
# Processed batch 19725 / 20000
# Processed batch 19726 / 20000
# Processed batch 19727 / 20000
# Processed batch 19728 / 20000
# Processed batch 19729 / 20000
# Processed batch 19730 / 20000
# Processed batch 19731 / 20000
# Processed batch 19732 / 20000
# Processed batch 19733 / 20000
# Processed batch 19734 / 20000
# Processed batch 19735 / 20000
# Processed batch 19736 / 20000
# Processed batch 19737 / 20000
# Processed batch 19738 / 20000
# Processed batch 19739 / 20000
# Processed batch 19740 / 20000
# Processed batch 19741 / 20000
# Processed batch 19742 / 20000
# Processed batch 19743 / 20000
# Processed batch 19744 / 20000
# Processed batch 19745 / 20000
# Processed batch 19746 / 20000
# Processed batch 19747 / 20000
# Processed batch 19748 / 20000
# Processed batch 19749 / 20000
# Processed batch 19750 / 20000
# Processed batch 19751 / 20000
# Processed batch 19752 / 20000
# Processed batch 19753 / 20000
# Processed batch 19754 / 20000
# Processed batch 19755 / 20000
# Processed batch 19756 / 20000
# Processed batch 19757 / 20000
# Processed batch 19758 / 20000
# Processed batch 19759 / 20000
# Processed batch 19760 / 20000
# Processed batch 19761 / 20000
# Processed batch 19762 / 20000
# Processed batch 19763 / 20000
# Processed batch 19764 / 20000
# Processed batch 19765 / 20000
# Processed batch 19766 / 20000
# Processed batch 19767 / 20000
# Processed batch 19768 / 20000
# Processed batch 19769 / 20000
# Processed batch 19770 / 20000
# Processed batch 19771 / 20000
# Processed batch 19772 / 20000
# Processed batch 19773 / 20000
# Processed batch 19774 / 20000
# Processed batch 19775 / 20000
# Processed batch 19776 / 20000
# Processed batch 19777 / 20000
# Processed batch 19778 / 20000
# Processed batch 19779 / 20000
# Processed batch 19780 / 20000
# Processed batch 19781 / 20000
# Processed batch 19782 / 20000
# Processed batch 19783 / 20000
# Processed batch 19784 / 20000
# Processed batch 19785 / 20000
# Processed batch 19786 / 20000
# Processed batch 19787 / 20000
# Processed batch 19788 / 20000
# Processed batch 19789 / 20000
# Processed batch 19790 / 20000
# Processed batch 19791 / 20000
# Processed batch 19792 / 20000
# Processed batch 19793 / 20000
# Processed batch 19794 / 20000
# Processed batch 19795 / 20000
# Processed batch 19796 / 20000
# Processed batch 19797 / 20000
# Processed batch 19798 / 20000
# Processed batch 19799 / 20000
# Processed batch 19800 / 20000
# Processed batch 19801 / 20000
# Processed batch 19802 / 20000
# Processed batch 19803 / 20000
# Processed batch 19804 / 20000
# Processed batch 19805 / 20000
# Processed batch 19806 / 20000
# Processed batch 19807 / 20000
# Processed batch 19808 / 20000
# Processed batch 19809 / 20000
# Processed batch 19810 / 20000
# Processed batch 19811 / 20000
# Processed batch 19812 / 20000
# Processed batch 19813 / 20000
# Processed batch 19814 / 20000
# Processed batch 19815 / 20000
# Processed batch 19816 / 20000
# Processed batch 19817 / 20000
# Processed batch 19818 / 20000
# Processed batch 19819 / 20000
# Processed batch 19820 / 20000
# Processed batch 19821 / 20000
# Processed batch 19822 / 20000
# Processed batch 19823 / 20000
# Processed batch 19824 / 20000
# Processed batch 19825 / 20000
# Processed batch 19826 / 20000
# Processed batch 19827 / 20000
# Processed batch 19828 / 20000
# Processed batch 19829 / 20000
# Processed batch 19830 / 20000
# Processed batch 19831 / 20000
# Processed batch 19832 / 20000
# Processed batch 19833 / 20000
# Processed batch 19834 / 20000
# Processed batch 19835 / 20000
# Processed batch 19836 / 20000
# Processed batch 19837 / 20000
# Processed batch 19838 / 20000
# Processed batch 19839 / 20000
# Processed batch 19840 / 20000
# Processed batch 19841 / 20000
# Processed batch 19842 / 20000
# Processed batch 19843 / 20000
# Processed batch 19844 / 20000
# Processed batch 19845 / 20000
# Processed batch 19846 / 20000
# Processed batch 19847 / 20000
# Processed batch 19848 / 20000
# Processed batch 19849 / 20000
# Processed batch 19850 / 20000
# Processed batch 19851 / 20000
# Processed batch 19852 / 20000
# Processed batch 19853 / 20000
# Processed batch 19854 / 20000
# Processed batch 19855 / 20000
# Processed batch 19856 / 20000
# Processed batch 19857 / 20000
# Processed batch 19858 / 20000
# Processed batch 19859 / 20000
# Processed batch 19860 / 20000
# Processed batch 19861 / 20000
# Processed batch 19862 / 20000
# Processed batch 19863 / 20000
# Processed batch 19864 / 20000
# Processed batch 19865 / 20000
# Processed batch 19866 / 20000
# Processed batch 19867 / 20000
# Processed batch 19868 / 20000
# Processed batch 19869 / 20000
# Processed batch 19870 / 20000
# Processed batch 19871 / 20000
# Processed batch 19872 / 20000
# Processed batch 19873 / 20000
# Processed batch 19874 / 20000
# Processed batch 19875 / 20000
# Processed batch 19876 / 20000
# Processed batch 19877 / 20000
# Processed batch 19878 / 20000
# Processed batch 19879 / 20000
# Processed batch 19880 / 20000
# Processed batch 19881 / 20000
# Processed batch 19882 / 20000
# Processed batch 19883 / 20000
# Processed batch 19884 / 20000
# Processed batch 19885 / 20000
# Processed batch 19886 / 20000
# Processed batch 19887 / 20000
# Processed batch 19888 / 20000
# Processed batch 19889 / 20000
# Processed batch 19890 / 20000
# Processed batch 19891 / 20000
# Processed batch 19892 / 20000
# Processed batch 19893 / 20000
# Processed batch 19894 / 20000
# Processed batch 19895 / 20000
# Processed batch 19896 / 20000
# Processed batch 19897 / 20000
# Processed batch 19898 / 20000
# Processed batch 19899 / 20000
# Processed batch 19900 / 20000
# Processed batch 19901 / 20000
# Processed batch 19902 / 20000
# Processed batch 19903 / 20000
# Processed batch 19904 / 20000
# Processed batch 19905 / 20000
# Processed batch 19906 / 20000
# Processed batch 19907 / 20000
# Processed batch 19908 / 20000
# Processed batch 19909 / 20000
# Processed batch 19910 / 20000
# Processed batch 19911 / 20000
# Processed batch 19912 / 20000
# Processed batch 19913 / 20000
# Processed batch 19914 / 20000
# Processed batch 19915 / 20000
# Processed batch 19916 / 20000
# Processed batch 19917 / 20000
# Processed batch 19918 / 20000
# Processed batch 19919 / 20000
# Processed batch 19920 / 20000
# Processed batch 19921 / 20000
# Processed batch 19922 / 20000
# Processed batch 19923 / 20000
# Processed batch 19924 / 20000
# Processed batch 19925 / 20000
# Processed batch 19926 / 20000
# Processed batch 19927 / 20000
# Processed batch 19928 / 20000
# Processed batch 19929 / 20000
# Processed batch 19930 / 20000
# Processed batch 19931 / 20000
# Processed batch 19932 / 20000
# Processed batch 19933 / 20000
# Processed batch 19934 / 20000
# Processed batch 19935 / 20000
# Processed batch 19936 / 20000
# Processed batch 19937 / 20000
# Processed batch 19938 / 20000
# Processed batch 19939 / 20000
# Processed batch 19940 / 20000
# Processed batch 19941 / 20000
# Processed batch 19942 / 20000
# Processed batch 19943 / 20000
# Processed batch 19944 / 20000
# Processed batch 19945 / 20000
# Processed batch 19946 / 20000
# Processed batch 19947 / 20000
# Processed batch 19948 / 20000
# Processed batch 19949 / 20000
# Processed batch 19950 / 20000
# Processed batch 19951 / 20000
# Processed batch 19952 / 20000
# Processed batch 19953 / 20000
# Processed batch 19954 / 20000
# Processed batch 19955 / 20000
# Processed batch 19956 / 20000
# Processed batch 19957 / 20000
# Processed batch 19958 / 20000
# Processed batch 19959 / 20000
# Processed batch 19960 / 20000
# Processed batch 19961 / 20000
# Processed batch 19962 / 20000
# Processed batch 19963 / 20000
# Processed batch 19964 / 20000
# Processed batch 19965 / 20000
# Processed batch 19966 / 20000
# Processed batch 19967 / 20000
# Processed batch 19968 / 20000
# Processed batch 19969 / 20000
# Processed batch 19970 / 20000
# Processed batch 19971 / 20000
# Processed batch 19972 / 20000
# Processed batch 19973 / 20000
# Processed batch 19974 / 20000
# Processed batch 19975 / 20000
# Processed batch 19976 / 20000
# Processed batch 19977 / 20000
# Processed batch 19978 / 20000
# Processed batch 19979 / 20000
# Processed batch 19980 / 20000
# Processed batch 19981 / 20000
# Processed batch 19982 / 20000
# Processed batch 19983 / 20000
# Processed batch 19984 / 20000
# Processed batch 19985 / 20000
# Processed batch 19986 / 20000
# Processed batch 19987 / 20000
# Processed batch 19988 / 20000
# Processed batch 19989 / 20000
# Processed batch 19990 / 20000
# Processed batch 19991 / 20000
# Processed batch 19992 / 20000
# Processed batch 19993 / 20000
# Processed batch 19994 / 20000
# Processed batch 19995 / 20000
# Processed batch 19996 / 20000
# Processed batch 19997 / 20000
# Processed batch 19998 / 20000
# Processed batch 19999 / 20000
# Processed batch 20000 / 20000

# %%
# Save the baseline predictions as CSV in-memory and upload directly to S3.
csv_buffer = io.StringIO()
baseline_df.to_csv(csv_buffer, index=False)
baseline_s3_key = "model_monitoring/baseline/baseline_test_predictions.csv"
s3_client = boto3.client('s3', region_name=region)
s3_client.put_object(Bucket=bucket_name, Key=baseline_s3_key, Body=csv_buffer.getvalue())
print(f"Baseline predictions uploaded to: s3://{bucket_name}/{baseline_s3_key}")
# Out:
# Baseline predictions uploaded to: s3://arxiv-project-bucket/model_monitoring/baseline/baseline_test_predictions.csv

# %%
#----------------------------- Model Monitoring ----------------------------

# %%
# Baseline dataset URIs
# For quality monitoring, the baseline predictions file (created previously)
baseline_dataset_uri = f"s3://{bucket_name}/model_monitoring/baseline/baseline_test_predictions.csv"
# For drift monitoring, we assume a baseline input file is available (created earlier) at:
baseline_input_uri = f"s3://{bucket_name}/model_monitoring/baseline/baseline_input.csv"

# S3 output location where monitoring job results (evaluation JSON files) will be saved
monitoring_output_uri = f"s3://{bucket_name}/model_monitoring/reports/"
print("Monitoring will target endpoint:", endpoint_name)
# Out:
# Monitoring will target endpoint: arxiv-clustering-endpoint20250304010548

# %%
# Define Monitoring Schedule Parameters to run every hour
schedule_expression = CronExpressionGenerator.hourly()

# Unique names for each monitoring schedule
quality_monitor_schedule_name = "arxiv-quality-monitor-" + datetime.utcnow().strftime("%Y%m%d%H%M%S")
drift_monitor_schedule_name = "arxiv-drift-monitor-" + datetime.utcnow().strftime("%Y%m%d%H%M%S")

# S3 URI for your custom evaluation scripts
custom_baseline_script_uri = f"s3://{bucket_name}/code/custom_baseline.py"
custom_drift_script_uri = f"s3://{bucket_name}/code/custom_drift.py"

print("Quality script URI:", custom_baseline_script_uri)
print("Drift script URI:", custom_drift_script_uri)
# Out:
# Quality script URI: s3://arxiv-project-bucket/code/custom_baseline.py
# Drift script URI: s3://arxiv-project-bucket/code/custom_drift.py

# %%
# Create an EndpointInput Object for captured data. Model monitoring processing job will use this to find captured data from endpoint
endpoint_input = EndpointInput(
    endpoint_name=endpoint_name,
    destination="/opt/ml/processing/input_data",
    inference_attribute="prediction"
)

# %%
# Quality (Drift) Monitoring Schedule runs a custom_baseline.py script to compute silhouette score on validation data
model_quality_monitor = ModelQualityMonitor(
    role=role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    volume_size_in_gb=20,
    max_runtime_in_seconds=1800,
    sagemaker_session=sess
)

quality_monitor_response = model_quality_monitor.create_monitoring_schedule(
    record_preprocessor_script=custom_baseline_script_uri,
    monitor_schedule_name=quality_monitor_schedule_name,
    endpoint_input=endpoint_input,
    output_s3_uri=monitoring_output_uri,
    problem_type="Regression",           # Silhouette score is continuous
    ground_truth_input=baseline_dataset_uri,
    schedule_cron_expression=schedule_expression
)
print("Quality monitoring schedule created:", quality_monitor_schedule_name)
# Out:
# [03/04/25 01:14:50] INFO     Ignoring unnecessary instance type: None.                            ]8;id=72726;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=887836;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py#530\530]8;;\
# [03/04/25 01:14:51] INFO     Creating Monitoring Schedule with name:                       ]8;id=189099;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model_monitor/model_monitoring.py\model_monitoring.py]8;;\:]8;id=214288;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model_monitor/model_monitoring.py#1560\1560]8;;\
#                              arxiv-quality-monitor-20250304011445
# Quality monitoring schedule created: arxiv-quality-monitor-20250304011445

# %%
# Data Drift Monitoring Schedule
# Runs the custom_drift.py script to compute drift metrics on input features and compares against our baseline
drift_monitor = ModelQualityMonitor(
    role=role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    volume_size_in_gb=20,
    max_runtime_in_seconds=1800,
    sagemaker_session=sess
)

drift_monitor_response = drift_monitor.create_monitoring_schedule(
    record_preprocessor_script=custom_drift_script_uri,
    monitor_schedule_name=drift_monitor_schedule_name,
    endpoint_input=endpoint_input,
    output_s3_uri=monitoring_output_uri,
    problem_type="Regression", # Choose regression because drift metric is continuous
    ground_truth_input=baseline_input_uri,
    schedule_cron_expression=schedule_expression
)
print("Data drift monitoring schedule created:", drift_monitor_schedule_name)
# Out:
# [03/04/25 01:14:56] INFO     Ignoring unnecessary instance type: None.                            ]8;id=521725;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=830460;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py#530\530]8;;\
#                     INFO     Creating Monitoring Schedule with name:                       ]8;id=110088;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model_monitor/model_monitoring.py\model_monitoring.py]8;;\:]8;id=126981;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/model_monitor/model_monitoring.py#1560\1560]8;;\
#                              arxiv-drift-monitor-20250304011445
# Data drift monitoring schedule created: arxiv-drift-monitor-20250304011445

# %%
# CloudWatch Alarms for Endpoint Metrics
# First is an Alarm on Invocation Error Rate (if the 5XX error count rises above threshold)
error_alarm_name = "Endpoint5XXErrorAlarm"
cw_client.put_metric_alarm(
    AlarmName=error_alarm_name,
    AlarmDescription="Alarm if 5XX error count exceeds threshold",
    ActionsEnabled=True,
    MetricName="Invocation5XXErrors",
    Namespace="AWS/SageMaker/Endpoints",
    Statistic="Sum",
    Dimensions=[{"Name": "EndpointName", "Value": endpoint_name}],
    Period=300,  # Evaluate every 5 minutes
    EvaluationPeriods=1,
    DatapointsToAlarm=1,
    Threshold=1,  # Trigger alarm if at least 1 error in a period
    ComparisonOperator="GreaterThanThreshold",
    TreatMissingData="notBreaching"
)
print("CloudWatch alarm created for 5XX error rate:", error_alarm_name)

# Alarm on Endpoint Latency (if average latency exceeds threshold)
latency_alarm_name = "EndpointLatencyAlarm"
cw_client.put_metric_alarm(
    AlarmName=latency_alarm_name,
    AlarmDescription="Alarm if endpoint latency exceeds threshold",
    ActionsEnabled=True,
    MetricName="Latency",
    Namespace="AWS/SageMaker/Endpoints",
    Statistic="Average",
    Dimensions=[{"Name": "EndpointName", "Value": endpoint_name}],
    Period=300,  # Evaluate every 5 minutes
    EvaluationPeriods=1,
    DatapointsToAlarm=1,
    Threshold=1000,  # If avg latency exceeds 1000 milliseconds
    ComparisonOperator="GreaterThanThreshold",
    TreatMissingData="notBreaching"
)
print("CloudWatch alarm created for endpoint latency:", latency_alarm_name)
# Out:
# CloudWatch alarm created for 5XX error rate: Endpoint5XXErrorAlarm
# CloudWatch alarm created for endpoint latency: EndpointLatencyAlarm

# %%
# Verify Monitoring Schedules
# Wait a bit and then describe the quality and drift schedules to verify they are created.
time.sleep(30)
quality_schedule_description = model_quality_monitor.describe_schedule()
print("Quality monitoring schedule description:")
print(quality_schedule_description)

drift_schedule_description = drift_monitor.describe_schedule()
print("Drift monitoring schedule description:")
print(drift_schedule_description)
# Out:
# Quality monitoring schedule description:
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:221082214706:monitoring-schedule/arxiv-quality-monitor-20250304011445', 'MonitoringScheduleName': 'arxiv-quality-monitor-20250304011445', 'MonitoringScheduleStatus': 'Scheduled', 'MonitoringType': 'ModelQuality', 'CreationTime': datetime.datetime(2025, 3, 4, 1, 14, 51, 280000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2025, 3, 4, 1, 14, 57, 750000, tzinfo=tzlocal()), 'MonitoringScheduleConfig': {'ScheduleConfig': {'ScheduleExpression': 'cron(0 * ? * * *)'}, 'MonitoringJobDefinitionName': 'model-quality-job-definition-2025-03-04-01-14-50-779', 'MonitoringType': 'ModelQuality'}, 'EndpointName': 'arxiv-clustering-endpoint20250304010548', 'ResponseMetadata': {'RequestId': '6b177f9e-6a58-4087-9fc1-0186d4733632', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '6b177f9e-6a58-4087-9fc1-0186d4733632', 'content-type': 'application/x-amz-json-1.1', 'content-length': '589', 'date': 'Tue, 04 Mar 2025 01:15:34 GMT'}, 'RetryAttempts': 0}}
# Drift monitoring schedule description:
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:221082214706:monitoring-schedule/arxiv-drift-monitor-20250304011445', 'MonitoringScheduleName': 'arxiv-drift-monitor-20250304011445', 'MonitoringScheduleStatus': 'Scheduled', 'MonitoringType': 'ModelQuality', 'CreationTime': datetime.datetime(2025, 3, 4, 1, 14, 57, 82000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2025, 3, 4, 1, 15, 5, 626000, tzinfo=tzlocal()), 'MonitoringScheduleConfig': {'ScheduleConfig': {'ScheduleExpression': 'cron(0 * ? * * *)'}, 'MonitoringJobDefinitionName': 'model-quality-job-definition-2025-03-04-01-14-56-616', 'MonitoringType': 'ModelQuality'}, 'EndpointName': 'arxiv-clustering-endpoint20250304010548', 'ResponseMetadata': {'RequestId': '5d3d28b5-3b71-4abc-aa87-1e03f87935b5', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5d3d28b5-3b71-4abc-aa87-1e03f87935b5', 'content-type': 'application/x-amz-json-1.1', 'content-length': '587', 'date': 'Tue, 04 Mar 2025 01:15:34 GMT'}, 'RetryAttempts': 0}}

# %%
#-------------------------------------------------------------------------------

# %%
# Deletion of all items listed to ensure closing of notebook and resources

# %%
'''
# Deletion of MOnitoring Drift Schedule
region = "us-east-1"
schedule_name = "arxiv-drift-monitor-20250228031805"

sm_client = boto3.client("sagemaker", region_name=region)
sm_client.delete_monitoring_schedule(MonitoringScheduleName=schedule_name)
print(f"Deleted monitoring schedule: {schedule_name}")
'''

# %%
'''
# Delition of Quality monitor
region = "us-east-1"
schedule_name = "arxiv-quality-monitor-20250228031805"

sm_client = boto3.client("sagemaker", region_name=region)
sm_client.delete_monitoring_schedule(MonitoringScheduleName=schedule_name)
print(f"Deleted monitoring schedule: {schedule_name}")
'''

# %%
# Deletion of endpoint
'''
sm_client = boto3.client('sagemaker', region_name=region)
# Leave variable below if used in current session, otherwise hardcode to kill because all are datetime stamped
# endpoint_name = "arxiv-clustering-endpoint20250303231924"
response = sm_client.describe_endpoint(EndpointName=endpoint_name)
print(response['EndpointStatus'])

print(f"Initiating deletion of endpoint: {endpoint_name}")
sm_client.delete_endpoint(EndpointName=endpoint_name)

# Poll until the endpoint is deleted
while True:
    try:
        response = sm_client.describe_endpoint(EndpointName=endpoint_name)
        status = response["EndpointStatus"]
        print("Endpoint status:", status)
        if status in ["InService", "Updating"]:
            time.sleep(10)
        else:
            print("Endpoint status is now", status)
            break
    except sm_client.exceptions.ClientError as e:
        # If endpoint is not found, it has been deleted.
        print("Endpoint deleted.")
        break

# Now delete the endpoint configuration
print(f"Deleting endpoint configuration: {endpoint_name}")
sm_client.delete_endpoint_config(EndpointConfigName=endpoint_name)
print("Endpoint configuration deleted.")
'''
